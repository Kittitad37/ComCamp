# %% [markdown]
# # 📚 เนื้อหาประกอบการเรียน <br>  COM104: Data Analytics and Visualization with Python 🐍 💻

# %% [markdown]
# ---

# %% [markdown]
# ## ℹ️ เกี่ยวกับ Notebook นี้

# %% [markdown]
# > Notebook นี้จัดทำขึ้นเพื่อประกอบการเรียนการสอนในรายวิชา COM104: การวิเคราะห์ข้อมูล และนำเสนอข้อมูลเบื้องต้นด้วย การเขียนโปรแกรมภาษาไพธอน (Data Analytics and Visualization with Python)
#
# 🚀 ภายใต้โครงการอบรมเชิงปฏิบัติการ [Comcamp ครั้งที่ 34](https://www.facebook.com/KMUTTcomcamp) ระหว่างวันที่ 9-13 เมษายน 2566
#
# ⚙️ ณ ภาควิชาวิศวกรรมคอมพิวเตอร์ คณะวิศวกรรมศาสตร์ มหาวิทยาลัยเทคโนโลยีพระจอมเกล้าธนบุรี
#
#
# ---

# %% [markdown]
# ![comcamp](https://scontent.fbkk22-6.fna.fbcdn.net/v/t39.30808-6/340250088_982902276198441_7153402634058411441_n.jpg?_nc_cat=102&ccb=1-7&_nc_sid=e3f864&_nc_eui2=AeGq7ujSnIMZBhPCT2HbA5j4PabTZncnwVc9ptNmdyfBV5tNWc97CK8dnvRyN8Bfrctj40Lu-XB4fGUvzPWYfEOO&_nc_ohc=kx6typ5mytoAX-UzuuJ&_nc_ht=scontent.fbkk22-6.fna&oh=00_AfANNI6w7HgERuXVS-mcC912gFpzuOyT8LEAnhz_iGUpsA&oe=6436CD0F)

# %% [markdown]
# ## 🔎 บทนำ: ชี้แจงรายละเอียด

# %% [markdown]
# **เอกสารที่เกี่ยวข้อง**
# *   แผนการเรียนรู้ฉบับย่อ (Course Syllabus)
# *   เอกสารประกอบการอบรม (Documentation)
#
# **สื่ออื่น ๆ ที่เกี่ยวข้อง**
#
#
# *   สไลด์นำเสนอประกอบการอบรม
# *   Notebook ฝึกอบรมปฏิบัติการ (Workshop)
#
#
# ---

# %% [markdown]
# ## ✏️ บทที่0: ชี้แจงการใช้งาน Notebook

# %% [markdown]
# บริเวณด้านบนน้อง ๆ จะสังเกตเห็น ปุ่มสำหรับเพิ่ม เซลล์ (cell) ซึ่งเป็นส่วนในการจดบันทึกภายใน Notebook นั่นเอง
# * **+Code** คือ เซลล์สำหรับการเขียนโค้ด และ แสดงผลลัพธ์การทำงาน
# * **+Text** คือ การเพิ่มเซลล์สำหรับการจดบันทึกข้อความ

# %% [markdown]
# ![Screenshot 2566-03-25 at 03.05.23.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %%
print("นี่คือเซลล์สำหรับเขียน Code ^ ^")
# Out:
# นี่คือเซลล์สำหรับเขียน Code ^ ^

# %% [markdown]
# พี่ๆคาบนี้หน้าตาดีมาก

# %% [markdown]
# ---

# %% [markdown]
# 😀 นี่คือเซลล์สำหรับบันทึกข้อความล่ะ!
#
# นอกเหนือจากนี้ยังสามารถใส่
# * 📸 **ภาพ**
#
# ![pixelcat](https://images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com/f/d0ffa37e-8ce1-42d7-a44c-9e7631404976/dd6gfv6-a4569dc4-e7b4-472d-bfb6-6bbd170b31e8.png/v1/fill/w_300,h_300,strp/that_cat_this_you_see_when_you_look_up_pixel_art_by_hikarukazumisenpai_dd6gfv6-fullview.png?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..UvFNNkKgtchSdGl6qnNKccVpQLC-1jQKTwrC_6AFmHM)
#
# * 📝 **ตาราง**
#
# เลขที่|ชื่อ
# -|-
# 1|สมชาย
# 2|สมเกียรติ
# 3|สมพงษ์

# %% [markdown]
# ## ✍🏻 บทที่1: ก้าวแรกสู่การวิเคราะห์ข้อมูล

# %% [markdown]
# ### 🟧 1.1 ความหมายของข้อมูล

# %% [markdown]
# **ข้อมูล (Data)** คือ ข้อเท็จจริง หรือ เรื่องราวที่เกี่ยวข้องกับสิ่งต่าง ๆ เช่น ผู้คน สิ่งของ สถานที่ ฯลฯ โดยอยู่ในรูปแบบที่เหมาะสมต่อการสื่อสาร การตีความ และ การประมวลผล ซึ่งวิธีการที่ได้มาซึ่งข้อมูลสามารถทำได้หลากหลายวิธี อาทิ การสังเกต การรวบรวม ซึ่งข้อมูลที่ได้รับสามารถเป็นได้ทั้ง ข้อความ ภาพ เสียง หรือ สัญลักษณ์ใด ๆ

# %% [markdown]
# **สารสนเทศ (Information)** ประกอบด้วยข้อมูลเอกสาร เสียง หรือรูปภาพต่าง ๆ แต่จัดเนื้อเรื่องให้อยู่ในรูปแบบที่สื่อความหมาย สารสนเทศมีที่มาจากข้อมูลที่ได้ผ่านกระบวนการประมวลผล อาจใช้วิธีเรียบง่าย อย่างการค่าทางสถิติพื้นฐาน เช่น ค่าเฉลี่ย  หรือใช้กระบวนการที่วิเคราะห์ในเชิงลึกมากขึ้น  ผ่านการวิเคราะห์ข้อมูล (Data Analysis)   เพื่อเปลี่ยนแปลงสภาพข้อมูลทั่วไปให้อยู่ในรูปแบบที่มีความสัมพันธ์หรือมมีนัยยะบางอย่าง เพื่อนำไปใช้ประโยชน์ในการตัดสินใจให้ตอบปัญหาต่าง ๆ ได้

# %% [markdown]
# ###🟧 1.2 ประเภทของข้อมูล

# %% [markdown]
# การแบ่งประเภทข้อมูลเบื้องต้นที่เป็นที่นิยม คือการการแบ่งประเภทของข้อมูลโดยอาศัยลักษณะของข้อมูล ได้แก่
#
# * **ข้อมูลเชิงปริมาณ (Quantitative data)**  คือข้อมูลที่เป็นตัวเลขที่ใช้แสดงปริมาณ
# เช่น ราคาวัตถุดิบ น้ำหนักสินค้า จำนวนพนักงาน ฯลฯ
# * **ข้อมูลเชิงคุณภาพ (Qualitative data)**  คือข้อมูลที่อธิบายลักษณะหรือสมบัติในเชิงคุณภาพ เช่น ความพึงพอใจในการบริการ รหัสสินค้า รายชื่อพนักงาน ฯลฯ

# %% [markdown]
# ###🟧 1.3 การวิเคราะห์ข้อมูล (Data Analysis)

# %% [markdown]
# **การวิเคราะห์ข้อมูล** เป็นกระบวนการในการนำข้อมูลมาสกัด หรือ แปลงความหมาย ให้เกิดประโยชน์ ต่อ การตัดสินใจ และ การแก้ไขปัญหาต่าง ๆ ตัวอย่างเช่น หากเราทำกิจการร้านสะดวกซื้อแล้วเกิดผลประกอบการขาดทุน เราก็สามารถวิเคราะห์ข้อมูลประวัติการขายสินค้าภายในร้านเรา เพื่อหาว่าสินค้าประเภทใดที่สร้างผลกำไรได้ดี หรือ สินค้าประเภทใดที่ลงทุนสูงแต่ได้รับความสนใจจากลูกค้าน้อย เมื่อทราบดังนี้เราก็สามารถเพิ่ม-ลด สินค้าภายในร้าน ให้เกิดผลประโยชน์สูงสุดกับเราได้ ดังนั้นการวิเคราะห์ข้อมูลจึงมีความสำคัญอย่างอย่างมาก ทั้งในแวดวงของธุรกิจ การวิจัย และแวดวงอื่น ๆ ที่ต้องอาศัยการพิจราณาข้อมูลเพื่อสนองความต้องการ หรือ แก้ไขปัญหาบางอย่าง

# %% [markdown]
# ## 🧑🏻‍💻 บทที่2: การเขียนโปรแกรมด้วยภาษา Python เบื้องต้น

# %% [markdown]
# ###🟩 2.1 Python Introduction

# %% [markdown]
# ####◻️ Python คืออะไร

# %% [markdown]
# **Python** คือ ภาษาโปรแกรมคอมพิวเตอร์ระดับสูงโดยออกแบบมาให้เป็นภาษาสคริปต์ที่อ่านง่าย มีโครงสร้าง ตัวแปร และไวยากรณ์คำสั่งต่าง ๆ ของภาษาที่ไม่ซับซ้อน เข้าใจง่าย โดยมีฟังก์ชันคำสั่งแยกเป็นสัดส่วน ๆ หรือ โมดูล (Modular) ไว้ให้เรียกใช้งานได้อย่างสะดวก นอกจากนี้ยังมีความหยืดหยุ่นในการทำงานร่วมกับภาษาอื่นอีกด้วย
#
# ![python](https://www.python.org/static/community_logos/python-logo-master-v3-TM-flattened.png)

# %% [markdown]
# ####◻️ เกร็ดความรู้💡 ใครเป็นคนคิดภาษา Python กันนะ?

# %% [markdown]
# ภาษา Python ถูกคิดค้นพัฒนาและสร้างโดย คีโด ฟัน โรสซึม ( Guido van Rossum ) โปรแกรมเมอร์ชาวดัตช์ โดยภาษาไพธอน ถูกปล่อยตัวให้ทั่วโลกใช้งานครั้งแรก                          วันที่ 20 กุมภาพันธ์ 1991  โดย Python เวอร์ชั่นล่าสุด คือ Python 3.11

# %% [markdown]
# ####◻️ เราสามารถเข้าถึงPythonได้จากที่ไหน

# %% [markdown]
# เปิดโปรแกรมเว็บเบราว์เซอร์และเข้าไปที่หน้าเว็บไซต์หลักทางการของ Python ที่ https://www.python.org เมื่อติดตั้งเสร็จสามารถรันโปรแกรมได้ที่ Command Prompt แล้วพิมพ์ว่า python / หรืออาจใช้โปรแกรมอื่น ๆ ในการเปิดตัว Python นี้ได้เช่นกัน

# %% [markdown]
# ###🟩 2.2 Jupyter Notebook/ Colab

# %% [markdown]
# ####◻️ Jupyter Notebook คืออะไร

# %% [markdown]
#  **Jupyter Notebook** คือ หน้าเว็บที่ประกอบด้วย ช่อง ๆ (cell) เรียงต่อกันลงไป โดยแต่ละ cell สามารถเป็นเนื้อหาต่าง ๆ เช่น ข้อความ รูปภาพ กราฟ วิดีโอ เสียง หรือ เป็นโค้ดโปรแกรมคอมพิวเตอร์ ภาษา Python ที่ สามารถรันคำสั่งประมวลผล แสดงผลลัพท์ออกมาได้  โดยข้อดีของ Jupyter Notebook สำหรับ Python นั้น คือช่อง cell จึงทำให้สามารถรันโค้ดได้เป็นส่วน ๆ (Block) ทำให้ง่ายต่อการเขียน ทดสอบ และแก้ไขข้อผิดพลาดที่เกิดขึ้นต่างจากโปรแกรมอื่นที่ต้องรันทั้งหมดเลย

# %% [markdown]
# ![jupyter-notebook-001.gif](data:image/gif;base64,...)
#
#
#
# > ภาพหน้าต่าง Jupyter notebook

# %% [markdown]
# ####◻️ Google Colab คืออะไร

# %% [markdown]
# **Google Colab**  หรือ Colaboratory  คือหนึ่งใน บริการเทคโนโลยีคลาวด์ (Cloud) จาก Google Research ที่อนุญาตให้ผู้ใช้เขียนซอร์สโค้ดในตัวแก้ไขและเรียกใช้จากบนเบราว์เซอร์ โดย รองรับภาษาการเขียนโปรแกรม Python (ในแบบสกุลไฟล์ของ Jupyter Notebook “ .ipynb ” ในขณะที่ สกุลไฟล์ดั้งเดิมของ Python คือ “ .py ” ) มีความสะดวกในการจัดเก็บไฟล์ โดยสามารถจัดเก็บไฟล์ของเราไว้ Google Drive ซึ่งเป็นบริการจัดเก็บข้อมูลส่วนตัว

# %% [markdown]
# ####◻️ เทคนิควิธีการใช้งาน Google Colab เบื้องต้น

# %% [markdown]
# *   เมื่อสร้างสมุดบันทึกใหม่แล้ว โดยสามารถเริ่มเขียนโค้ดในเซลล์ที่กำหนดไว้ได้ สามารถเพิ่มเซลล์เพิ่มเติมได้โดยคลิกที่ปุ่ม "+" ด้านบนของสมุดบันทึก
# *   ในการรันเซลล์ ให้คลิกที่ปุ่ม "play" ทางด้านซ้ายของเซลล์หรือกดปุ่ม "Shift + Enter"
# *สามารถบันทึกสมุดบันทึกลงใน Google Drive ได้โดยคลิกที่ "File" -> "Save a copy in Drive".
# *เมื่อเสร็จสิ้นแล้ว สามารถแชร์สมุดบันทึกกับผู้อื่นได้โดยคลิกที่ "Share" ที่มุมขวาบน.

# %% [markdown]
# ###🟩 2.3 ประเภทของข้อมูล (Data Types)

# %% [markdown]
# ####◻️ ประเภทข้อมูลคืออะไร

# %% [markdown]
# **ประเภทข้อมูล** หรือ Data Type คือลักษณะการจัดเก็บข้อมูล ที่สามารถเก็บข้อมูลและใช้งานตามลักษณะที่ได้ระบุไว้ใน Python โดย               ใน Python นั้นมีให้เราเลือกเก็บมากมาย แต่ก็จะมีเพียง 6 ประเภทที่เราจะได้ใช้งานกันบ่อย ๆ

# %% [markdown]
# ####◻️ ตัวแปร (Variable)

# %% [markdown]
# **ตัวแปร** หรือ Variable คือ ชื่อที่ตั้งขึ้นมาเพื่ออ้างอิงถึงตำแหน่งหน่วยความจำที่ใช้จัดเก็บข้อมูล และสามารถเรียกสมาชิก ซึ่งคือ ค่าข้อมูลที่เก็บอยู่ (value) ออกมาใช้ได้
# โดยตัวแปรนั้น สามารถเก็บค่าได้หลากหลายแบบ เช่น เลขจำนวนเต็ม เลขทศนิยม หรือ ตัวอักษร เป็นต้น
#
#
# ในภาษา Python นั้นเราไม่จำเป็นต้องประกาศตัวแปรเหมือน ภาษา C

# %%
#Variables  =  Value 
name = "James"
score = 100

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ####◻️ ดัชนี (Index)

# %% [markdown]
# วิธีการดึงข้อมูล (ดึงตามตำแหน่งที่สมาชิกอยู่) โดย **index** หรือ ในภาษาไทยง่าย ๆ คือ ตัวชี้ โดยในภาษา python จะเริ่มที่เลขศูนย์ (0) และ ถ้าเราใช้ negative index เลขลบหนึ่ง (-1) จะดึงข้อมูลตัวสุดท้ายที่อยู่ในตัวแปรนั้น ซึ่งเราจะใช้เครื่องหมาย square bracket [ _ ] และ [ _ : _ ] ในการดึงข้อมูลที่อยู่ใน ตัวแปรนั้น สามารถแบ่งออกเป็นสองวิธี คือ indexing และ slicing

# %% [markdown]
# ##### Indexing

# %% [markdown]
# วิธีการ **Indexing** เป็นการเลือกสมาชิกแค่ตำแหน่งเดียว

# %%
name = "James"
print(name[0])
print(name[3])
print(name[-1])
# Out:
# J
# e
# s

# %% [markdown]
# ##### Slicing

# %% [markdown]
# วิธีการ **slicing** เป็นการเลือกสมาชิกตั้งแต่ 1 ตัวขึ้นไป เช่น [0:2] จะดึงข้อมูล index ที่ 0, 1 แต่ไม่รวม 2 (นับ แต่ไม่เอา เอาตัวที่อยู่ก่อนหน้าแทน) ถ้าเราเขียน [1:] จะเป็นการดึงข้อมูลตั้งแต่ index ที่ 1 ไปจนถึงตัวสุดท้ายของ Lists นั้น ๆ เป็นต้น

# %%
name = "BRIAN"
print(name[0:2])
# Out:
# BR

# %%
name = "BRAIN"
print(name[1:])
# Out:
# RAIN

# %% [markdown]
# ####◻️ ข้อความ (String)

# %% [markdown]
# **String** หรือ ข้อความ เป็นชนิดของข้อมูลที่ใช้เก็บข้อความที่เป็นตัวอักษรและตัวเลข โดย ข้อความจะต้องอยู่ใน Single quote (‘ __ ’) หรือ Double quote (“ __ ”)

# %%
name = "Mee"

# %%
type(name)
# Out:
# str

# %% [markdown]
# ####◻️ ตัวเลข (Number)

# %% [markdown]
# **Number** หรือ ตัวเลข สามารถแบ่งได้ออกเป็น 3 ประเภทย่อย ๆ
#
#
# 1.   **จำนวนเต็ม** (Integer / int) จำนวนเต็มเป็นชนิดข้อมูลที่เก็บตัวเลข			ที่เป็นจำนวนเต็ม ซึ่งตัวเลขสามารถมีค่า ติดลบ ได้
# 2.   **เลขทศนิยม** (Floats)  เลขทศนิยม เป็นชนิดข้อมูลที่เก็บตัวเลขที่เป็นทศนิยม
# 3.**จำนวนเชิงซ้อน** (Complex) จำนวนเชิงซ้อน เป็นชนิดข้อมูลที่เก็บตัวเลขที่		เป็นจำนวนเชิงซ้อน (Imaginary number)

# %%
333

# %%
type(3.14)

# %%
type(3+4j)

# %% [markdown]
# ####◻️ ลิสต์(Lists)

# %% [markdown]
# **Lists** เป็นการเก็บข้อมูลหลาย ๆ ตัวไว้ในตัวแปรเดียวโดยใช้เครื่องหมาย Square brackets ( [ A , B, C ] ) และ ภายในสมาชิกแต่ละตัวของ Lists จะถูกคั่นด้วย	เครื่องหมาย comma หรือ ลูกน้ำ ( , ) โดย Lists นั้นสามารถเพิ่มหรือลดสมาชิกได้

# %%
food = ["egg","bread","milk"]
print(food)

# %%
list_of_names = ["Kantapong","Kittipong","Chotanansub","Chotanansub","Kittipong"]
list_of_numbers = [2,4,6,7,10,10,2,2,2,2,2,2]
list_of_colors = ["🔴","🔵","🟢","🟠","🟢","🟢","🟠"]

print(list_of_names)
print(list_of_colors)
print(list_of_numbers)

print("\nสีแรกในลิสต์ก็คือ: ", list_of_colors[0])
print("สีที่สองในลิสต์ก็คือ: ", list_of_colors[1])
print("สีที่สุดท้ายในลิสต์ก็คือ: ", list_of_colors[-1])

print("\nสีแรกถึงสีที่สามในลิสต์ก็คือ: ", list_of_colors[0:3])
print("สีที่สองจนถึงสีสุดท้ายในลิสต์ก็คือ: ", list_of_colors[1:])

# %% [markdown]
# ##### การจัดการลิสต์ (Lists Manipulation)

# %% [markdown]
# Lists จะมีฟังก์ชันเฉพาะของตัวมันเองหรือที่เราเรียกว่า “lists methods” ในการจัดการ Lists โดย ตัวหลัก ๆ ที่เราใช้บ่อย ๆ เช่น

# %% [markdown]
# ###### `.append()`

# %% [markdown]
# ในตัวอย่างด้านล่าง เป็นการกำหนดค่าให้กับ Lists หลังจากที่มันถูกสร้างแล้ว เราใช้ **append()** เพื่อเพิ่มข้อมูลใหม่เข้าไปใน Lists ซึ่งข้อมูลที่เพิ่มเข้าจะอยู่ท้ายสุดและเรียง Index เพิ่มขึ้นไปเรื่อย ๆ โดยเริ่มจาก 0

# %%
teacher_list = ["Mee","'Fluke"]

# %%
teacher_list.append("Zom")
teacher_list

# %% [markdown]
# ###### `.remove()`

# %% [markdown]
#  เรายังสามารถลบข้อมูลใน Lists ได้อีกด้วยโดยใช้คำสั่ง **remove  (value)** วิธีนี้เราจะสามารถลบข้อมูลจากใน Lists ที่มีค่าตามที่เราได้ระบุลงไป

# %%
teacher_list.remove("Mee")
teacher_list

# %% [markdown]
# ###### `.pop()`

# %% [markdown]
# ถ้าเราต้องการลบ item ใน List ให้ใช้ **.pop()** โดย default pop จะลบ item ตัวสุดท้ายใน Lists เราสามารถกำหนด index ของ item ที่ต้องการลบได้ตามตัวอย่างนี้

# %%
teacher_list = ["Mee","Fluke","Flourbag"]
teacher_list.pop(1)
teacher_list

# %% [markdown]
# ###### `.sort()`

# %% [markdown]
# ใช้ในการเรียงข้อมูลใน List สามารถ **sort()** ได้ทั้งตัวเลขและตัวอักษร default จะเป็นการเรียงจากน้อยไปมาก (หรือ a-z) ถ้าเราเซ็ต reverse = True จะเป็นการเรียงจากมากไปน้อย

# %%
number = [1,6,3,8,6,4]
number.sort()
number

# %%
number = [1,6,3,8,6,4]
number.sort(reverse = True)
number

# %% [markdown]
# ###### `.insert()`

# %% [markdown]
# **insert()**  คือคำสั่งเพิ่มข้อมูลลงในตัวแปร Lists ซึ่งแตกต่างจากคำสั่ง append ตรงที่คำสั่ง append จะเพิ่มไว้ที่ลำดับสุดท้าย แต่คำสั่ง insert สามารถกำหนดได้ว่าข้อมูลใหม่ที่เพิ่มจะอยู่ในลำดับที่เท่าไร สามารถเขียนโปรแกรมได้ดังนี้

# %%
number = [1,6,3,8,6,4]
number.insert(2,"five")
number

# %% [markdown]
# ###### `len()`

# %% [markdown]
# **Len()** คือ คำสั่งสำหรับนับจำนวน กรณีถ้าใช้คำสั่ง len กับข้อความจะเป็นการนับจำนวนตัวอักษร และถ้าใช้คำสั่ง len กับตัวแปร Lists จะเป็นการนับจำนวนข้อมูลในตัวแปร Lists สามารถเขียนโปรแกรมได้ดังนี้

# %%
teacher_list = ["Mee","Fluke","Chokun"]
len(teacher_list)

# %%
name = 'Python'
print(len(name))

# %%
name = ['Python','PHP','Java','Go']
print('The amount of data in the lists = ' + str(len(name)))

# %% [markdown]
# ###### `Update Value in Lists`

# %% [markdown]
# เราสามารถอัพเดทค่าที่อยู่ใน Lists ได้ ตัวอย่างด้านล่างเราอัพเดทค่าของ item

# %%
number = [1,6,3,8,6,4]
number[0] = 100
number

# %% [markdown]
# ####◻️ เซต (Set)

# %% [markdown]
# **เซต** นั้นเป็นการเก็บข้อมูลหลาย ๆ ตัวเหมือน Lists แต่มีการเก็บข้อมูล ที่ไม่ซ้ำกันภายในลิสต์ เหมือนเซตในคณิตศาสตร์ที่เราเรียนกัน เซต นั้นใช้ เครื่องหมาย Curly brackets ( { 1, 2 , 3 } ) และ ภายในสมาชิกแต่ละตัวของ เซตจะถูกคั่นด้วย เครื่องหมาย comma หรือ ลูกน้ำ ( , )

# %%
set_of_names = {"Kantapong","Kittipong","Chotanansub","Chotanansub","Kittipong"}
set_of_numbers = {2,4,6,7,10,10,2,2,2,2,2,2}
set_of_colors = {"🔴","🔵","🟢","🟠","🟢","🟢","🟠"}

print(set_of_names)
print(set_of_colors)
print(set_of_numbers)

# %% [markdown]
# ####◻️ ทูเปิล (Tuple)

# %% [markdown]
# **Tuple** นั้นเป็นการเก็บข้อมูลหลาย ๆ ตัวและการเข้าถึงที่มีลำดับชัดเจน คล้ายกับ Lists สามารถคัดลอกข้อมูลได้ แต่ไม่สามารถแก้ไขเพิ่มลดสมาชิกภายในได้  Tuple นั้นใช้เครื่องหมาย brackets (   ) และ ภายในสมาชิกแต่ละตัวของ Tuple จะถูกคั่นด้วย เครื่องหมาย comma หรือ ลูกน้ำ ( , )

# %%
tuple_of_names = ("Kantapong","Kittipong","Chotanansub","Chotanansub","Kittipong")
tuple_of_numbers = (2,4,6,7,10,10,2,2,2,2,2,2)
tuple_of_colors = ("🔴","🔵","🟢","🟠","🟢","🟢","🟠")

print(tuple_of_names)
print(tuple_of_colors)
print(tuple_of_numbers)

# %% [markdown]
# ####◻️ ดิกชันนารี (Dictionary / dict)

# %% [markdown]
#  **Dictionary** นั้นเป็นการเข้าถึงข้อมูลในรูปแบบ Key : Value ( colon “ : ” ขั้นกลาง) เหมือนกับที่เราเปิดดิกชันนารีแปลคำศัพท์ภาษาอังกฤษโดยที่เรา เข้าถึงคำศัพท์แล้วเราก็จะได้ความหมายของคำนั้น ๆ โดย dict ใช้เครื่องหมาย	Curly brackets ( { “Name” : “James” } ) ในการเก็บค่าข้อมูล ซึ่งข้อมูลใน dict 	สามารถอัพเดต เปลี่ยนแปลง และ ลบออกได้

# %%
Bigc = {"Chicken" : 70, "Tomato": 20, "Soap" : 30 }

# %%
print(Bigc)

# %%
print(Bigc["Chicken"])

# %% [markdown]
# ---

# %% [markdown]
# ###🟩  2.4 ตัวเนินการ (Operators)

# %% [markdown]
# **ตัวดำเนินการ** คือ เครื่องหมาย หรือสัญลักษณ์ที่ใช้ในการดำเนินการกับตัวแปรหรือค่าต่าง ๆ

# %% [markdown]
# ####◻️ 2.4.1 ตัวดำเนินการทางคณิตศาสตร์ (Arithmetic Operators)

# %% [markdown]
# > ตารางที่ 1 คำอธิบายตัวดำเนินการทางคณิตศาสตร์และตัวอย่างการใช้งาน
#
#
#
# | ตัวดำเนินการ  | อธิบาย  |  ตัวอย่าง |
# |---|---|---|
# |  + | บวก  |  a + b มีค่า 30 |
# |  - | ลบ  |  a - b มีค่า -10 |
# |  * |  คูณ | a * b มีค่า 200   |
# | /| หาร|    b / a มีค่า 2 |
# |% | เศษที่เหลือจากการหาร|b % a มีค่า 0 |
# |**|ยกกำลัง |a**b หมายถึง 10 ยกกำลัง 20 |
# |//|หารปัดเศษทิ้ง |9//2 is มีค่า 4 และ 9.0//2.0 มีค่า 4.0 |

# %%
a=10
b=20
print("a =", a  , "b =", b)
print("a+b = ",a+b)
print("a-b = ",a-b)
print("a*b = ",a*b)
print("a/b = ",a/b)
print("b%a = ",b%a)
print("a**b = ",a**b)
print("9//2 = ",9//2)
# Out:
# a = 10 b = 20
# a+b =  30
# a-b =  -10
# a*b =  200
# a/b =  0.5
# b%a =  0
# a**b =  100000000000000000000
# 9//2 =  4

# %% [markdown]
# ####◻️ 2.4.2 ตัวดำเนินการเปรียบเทียบ (Comparision Operators)

# %% [markdown]
# > ตารางที่ 2 คำอธิบายตัวดำเนินการเปรียบเทียบ และ ตัวอย่างการใช้งาน
#
#
#
# | ตัวดำเนินการ  | อธิบาย  |  ตัวอย่าง |
# |---|---|---|
# |  == | เช็คว่าค่าสองค่าเท่ากันหรือไม่ |  (a == b) เป็นเท็จ |
# |  != | เช็คว่าค่าสองค่าไม่เท่ากันหรือไม่  | (a != b) เป็นจริง |
# |  > |  เช็คว่าค่าทางซ้ายมากกว่าค่าทางขวาหรือไม่ | (a > b) เป็นเท็จ   |
# |<| เช็คว่าค่าทางซ้ายน้อยกว่าค่าทางขวาหรือไม่| (a < b) เป็นจริง |
# |>= | เช็คว่าค่าทางซ้ายมากกว่าหรือเท่ากับค่าทางขวาหรือไม่|(a >= b) เป็นเท็จ |
# |<=|เช็คว่าค่าทางซ้ายน้อยกว่าหรือเท่ากับค่าทางขวาหรือไม่ |(a <= b) เป็นจริง |

# %%
a = 10
b = 20
a == b
# Out:
# False

# %% [markdown]
# ####◻️ 2.4.3 ตัวดำเนินการทางตรรกะ ( Logical Operators)

# %% [markdown]
# > ตารางที่ 3 คำอธิบายตัวดำเนินการทางตรรกะ และ ตัวอย่างการใช้งาน
#
#
# |ตัวดำเนินการ| อธิบาย |ตัวอย่าง |
# |---|---|---|
# |and|เช็คว่าทั้งสองตัวเป็นจริงถึงจะคืนค่าจริง กรณีอื่นๆเป็น เท็จทั้งหมด|(a and b) เป็นจริง.|
# or|ถ้าทั้งสองตัวหนึ่งเป็นเท็จจะคืนค่า เท็จกรณีอื่นๆเป็นจริงทั้งหมด|(a or b) เป็นจริง.|
# not |คืนค่าตรงกันข้ามของค่าปัจจุบัน|not(a and b)เป็นเท็จ เพราะ a and b เป็นจริง.|

# %% [markdown]
# ####◻️ 2.4.4 ตัวดำเนินการกำหนดค่า (Assignment Operators)

# %% [markdown]
# > ตารางที่ 4 คำอธิบายตัวดำเนินการกำหนดค่า และ ตัวอย่างการใช้งาน
#
# |ตัวดำเนินการ|อธิบาย|ตัวอย่าง|
# |---|---|---|
# |=|ตัวแปรทางซ้ายถูกกำหนดให้มีค่าเท่ากับทางขวา|c = a + b เป็นการกำหนดค่าให้กับ c โดยให้มีค่าเท่ากับ a + b|
# |+=|บวกค่าของทางซ้ายด้วยค่าทางขวา|c += a  หมายความว่า c = c + a|
# |-=|ลบค่าของทางซ้ายด้วยค่าทางขวา|c -= a หมายความว่า c = c - a|
# *=|คูณค่าของทางซ้ายด้วยค่าทางขวา|c *= a หมายความว่า c = c * a
# |/=|หารค่าของทางซ้ายด้วยค่าทางขวา|c /= a หมายความว่า c = c / a
# %=|หารเอาเศษค่าของทางซ้ายด้วยค่าทางขวา|c %= a หมายความว่า c = c % a
# **=|ยกกำลังค่าของทางซ้ายด้วยค่าทางขวา|c **= a หมายความว่า c = c ** a
# //=|หารปัดเศษทิ้งค่าของทางซ้ายด้วยค่าทางขวา|c //= a หมายความว่า c = c // a

# %%
item = 0
item = item + 1
print(item)
# Out:
# 1

# %%
item = 0
item += 1
print(item)
# Out:
# 1

# %% [markdown]
# ####◻️ 2.4.5 ตัวดำเนินการสมาชิก (Membership Operators)

# %% [markdown]
# **ตัวดำเนินการสมาชิกเป็น**  คำสั่งไว้สำหรับเช็คว่า ค่าที่เรากำลังสนใจเป็นสมาชิกของตัวแปรนั้น ๆ หรือไม่ จะคืนค่าเป็น จริงหรือเท็จแล้วแต่กรณีใช้กับ strings, lists, or tuple

# %% [markdown]
# **เป็นตัวดำเนินการพิเศษของภาษา Python จะไม่พบในภาษาอื่น**

# %% [markdown]
# >ตารางที่ 5 คำอธิบายตัวดำเนินการสมาชิกและตัวอย่างการใช้งาน

# %% [markdown]
# |ตัวดำเนินการ|อธิบาย|ตัวอย่าง|
# |---|---|---|
# |in|จะคืนค่าเป็นจริงถ้า พบค่าในตัวแปรที่เราสนใจ ในกรณีอื่นเป็นเท็จทั้งหมด|x in y, คือค่าเป็น True ถ้า x เป็นสมาชิกของ y.
# not in|จะคืนค่าเป็นจริงถ้าไม่พบค่าในตัวแปรที่เราสนใจ ในกรณีอื่นเป็นเท็จทั้งหมด|x not in y, คือค่าเป็น True ถ้า x ไม่เป็นสมาชิกของ y

# %%
teacher_list = ["Mee","Fluke"]
"Mee" in teacher_list
# Out:
# True

# %%
teacher_list = ["Mee","Fluke"]
"Chokun" in teacher_list
# Out:
# False

# %% [markdown]
# ####◻️ 2.4.6 ลำดับความสำคัญของ Operator (Operator Precedence)

# %% [markdown]
# >ตารางที่ 6 คำอธิบายตัวดำเนินการแบบแสดงเอกลักษณ์และตัวอย่างการใช้งาน
#
# |ลำดับ |Operator|
# |---|---|
# 1|( )
# 2|!
# 3|* , / , %
# 4|+, -
# 5|< , <= , >= , >
# 6|== , !=
# 7|& (and)
# 8|^ (or)
# 9|*= , /= , %= , += , -=

# %%
4 + 5 *5
# Out:
# 29

# %%
(4 + 5)*5
# Out:
# 45

# %% [markdown]
# ####◻️ 2.4.7 คำสั่งพื้นฐาน (Basic syntax)

# %% [markdown]
# ##### `print()`

# %% [markdown]
# คำสั่ง **print()**  ในภาษาไพธอน เป็นคำสั่งที่เอาไว้ใช้สำหรับ แสดงค่าหรือข้อมูลออกทางหน้าจอผลการรัน ซึ่งคล้าย ๆ กับในภาษาโปรแกรมอื่น แต่แพลตฟอร์มต่างกันนิดหน่อย ซึ่งคำสั่ง print นี้มีวิธีการใช้ค่อนข้างหลากหลาย และเป็นคำสั่งที่สำคัญมากในการเขียนโปรแกรม

# %% [markdown]
# **แบบ Single / Double quote** (ใช้ในการเขียนทั่วไป)

# %%
print("ห้ามตัวเองไม่ให้รักเธอจะทำยังไงใจมันไม่ฟัง หัวใจฉันยังเกเรทุกครั้ง ดึงดันไปรักเธอ ห้ามตัวเองว่าพอซักที กับเธอคนนี้ไม่ต้องไปเจอ ไม่มีวันเป็นเจ้าของใจเธอ ใจมันยังเกเรเสมอ ไม่เคยจะเชื่อฟัง")
# Out:
# ห้ามตัวเองไม่ให้รักเธอจะทำยังไงใจมันไม่ฟัง หัวใจฉันยังเกเรทุกครั้ง ดึงดันไปรักเธอ ห้ามตัวเองว่าพอซักที กับเธอคนนี้ไม่ต้องไปเจอ ไม่มีวันเป็นเจ้าของใจเธอ ใจมันยังเกเรเสมอ ไม่เคยจะเชื่อฟัง

# %% [markdown]
# **แบบ triple quote**   (ใช้สำหรับการเขียนเว้นเป็นบรรทัด ๆ ได้)

# %%
print("""ห้ามตัวเองไม่ให้รักเธอจะทำยังไงใจมันไม่ฟัง
หัวใจฉันยังเกเรทุกครั้ง ดึงดันไปรักเธอ
ห้ามตัวเองว่าพอซักที กับเธอคนนี้ไม่ต้องไปเจอ
ไม่มีวันเป็นเจ้าของใจเธอ ใจมันยังเกเรเสมอ ไม่เคยจะเชื่อฟัง""")
# Out:
# ห้ามตัวเองไม่ให้รักเธอจะทำยังไงใจมันไม่ฟัง
# หัวใจฉันยังเกเรทุกครั้ง ดึงดันไปรักเธอ
# ห้ามตัวเองว่าพอซักที กับเธอคนนี้ไม่ต้องไปเจอ
# ไม่มีวันเป็นเจ้าของใจเธอ ใจมันยังเกเรเสมอ ไม่เคยจะเชื่อฟัง

# %% [markdown]
# **แบบ text + variable** (ใช้สำหรับการเขียนข้อความรวมกับตัวแปร)

# %%
a = 3000
print("I love you "+ str(a))
# Out:
# I love you 3000

# %%
print("I love %s"%a)
# Out:
# I love 3000

# %%
a = 1
print("I love you %.4i"%a)
# Out:
# I love you 0001

# %% [markdown]
# ##### `type()`

# %% [markdown]
# คำสั่ง **type()** ในภาษาไพธอน เป็นคำสั่งที่เอาไว้ใช้สำหรับ แสดงประเภทของข้อมูลนั้น ๆ ออกทางหน้าจอผลการรัน

# %%
type(2.5)
# Out:
# str

# %%
Bigc = {"Chicken" : 70, "Tomato": 20, "Soap" : 30 }
type(Bigc)
# Out:
# dict

# %% [markdown]
# ##### `input()`

# %% [markdown]
# **input()** คือ คำสั่งรับค่าจากผู้ใช้งานผ่าน command prompt โดยค่าที่รับเข้ามาผ่านคำสั่ง input ของภาษา Python จะเป็นข้อมูลชนิดข้อความ / ตัวอักษร (String) หากต้องการข้อมูลชนิดอื่นต้องแปลงค่าดังกล่าว สามารถเขียนโปรแกรมได้ดังนี้

# %%
name = input('น้องชื่ออะไร : ')
print('น้องชื่อ',name)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-a90d756b517f> in <cell line: 1>()
# ----> 1 name = input('น้องชื่ออะไร : ')
#       2 print('น้องชื่อ',name)
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
# ...

# %% [markdown]
# ในตัวอย่างนี้เรามีการกำหนดให้เรารับค่าประเภทข้อมูลแค่เป็นเลขจำนวนเต็ม (int) ดังนั้นเมื่อเราใส่ประเภทข้อมูลประเภทอื่นจะเกิด Error ทันที

# %%
money = int(input("มีเงินเท่าไหร่ :"))
print("มีเงินแค่", money , "บาท" )

# %% [markdown]
# ####◻️ 2.4.8 Dict vs Lists

# %% [markdown]
# **Python Dictionary**
#
# Dictionary คือประเภทข้อมูลที่เก็บข้อมูลในรูปแบบคู่ของ Key และ Value โดยที่ Key ใช้สำหรับเป็น Index ในการเข้าถึงข้อมูลและ Value เป็นค่าข้อมูลที่สอดคล้องกับ Key ของมัน การเข้าถึงข้อมูลใน Dictionary นั้นรวดเร็วเพราะว่าข้อมูลได้ถูกทำ Index ไว้อัตโนมัติโดยใช้ Key

# %% [markdown]
# **Dictionary vs Lists**
#
# ลองดูตัวอย่างเปรียบเทียบ Lists กับ Dictionary นะครับ นึกภาพว่าเรามีภาพยนตร์สักเรื่องและคุณต้องการเก็บคะแนนไว้สำหรับพวกมัน นอกจากนี้เราต้องการเข้าถึงการจัดเรตติ้งของภาพยนตร์อย่างรวดเร็วด้วยชื่อภาพยนตร์ เราสามารถทำได้โดยใช้ 2 Lists หรือ 1 Dictionary ในตัวอย่าง คำสั่ง movies.index (“ Thor Ragnarok”) จะส่งคะแนนสำหรับภาพยนตร์ “Thor Ragnarok”

# %%
movie = ["Thor Ragnarok","Mad Max: Fury Road","Avatar"]
rating = [7.7,8.1,9.8]

movie_choice_index = movie.index("Thor Ragnarok")
print(rating[movie_choice_index])

# %%
rating = {
    "Thor Ragnarok" : 7.7,
    "Mad Max: Fury Road" : 8.1,
    "Avatar":9.8
}

print(rating["Thor Ragnarok"])

# %% [markdown]
# การจัดอันดับภาพยนตร์โดยใช้ Dictionary จากตัวอย่างจะเห็นว่าในกรณีนี้การใช้ Dictionary เป็นวิธีที่ง่ายและสะดวกยิ่งขึ้นในการแสดงการจัดอันดับการให้คะแนนภาพยนตร์

# %% [markdown]
# ###🟩 2.5 เงื่อนไข (Conditions)

# %% [markdown]
# เวลาเขียน Conditional Statements เราคิดง่าย ๆ ว่า “ถ้า <แบบนี้> จะให้ทำอะไร” คิดตรรกะง่าย ๆ ตรงไปตรงมา โดยทั่วไปจะมีรูปแบบการเขียนคำสั่งนี้จะเป็นอย่างนี้

# %% [markdown]
# ####◻️ 2.5.1 if

# %% [markdown]
# คำสั่ง “ถ้า” เขียนในรูปแบบนี้

# %% [markdown]
# ```python
# #ตัวอย่างโครงสร้าง
# if <เงื่อนไข> :
#   <คำสั่งที่ดำเนินการเมื่อเข้าตามเงื่อนไข>
# ```

# %% [markdown]
# ---
#
#
# * **<เงื่อนไข>** คือตัวกำหนดว่าจะใช้อะไรเป็นตัวตัดสินใจ ซึ่งจะต้องเป็น  Boolean หรือ ตรรกะ (ถูกหรือผิด ใช่หรือไม่ใช่)
#
#
# * **<คำสั่งที่ดำเนินการเมื่อเข้าตามเงื่อนไข>**
# คือ statement หรือคำสั่งที่จะประมวลผลเมื่อตรงตามเงื่อนไข ซึ่งจะต้องมีการ “เยื้อง” (หรือ “ย่อหน้า”) หรือ indent หรือการจัดบล็อกให้กับคำสั่ง
#
#
# ---

# %% [markdown]
# ในการเขียนโค้ด Python การสร้างชุดคำสั่งหนึ่ง ขอให้มองเป็นบล็อก โดยมีการเยื้อง (indent) เป็นตัวช่วยแสดงบล็อก จะช่วยให้เรามองลูปหรือคำสั่งตามเงื่อนไขได้ง่ายขึ้น ถ้าหากเป็นไปตามเงื่อนไข - คำสั่งที่ดำเนินการเมื่อเข้าตามเงื่อนไข- จะเขียนให้อยู่ในรูปบล็อก โดยใช้การเยื้องเป็นตัวช่วย

# %%
score = 70
if score > 60:
  print("ผ่านจ้า")

# %% [markdown]
# บรรทัดแรก `score = 70`  คือการกำหนดค่าให้ score = 70
#
# บรรทัดสอง `if score > 60:` คือการตั้งเงื่อนไขว่า คะแนนที่ได้ มากกว่า 60 หรือไม่
#
# บรรทัดสาม `print(“ผ่านจ้า”)`  แสดงผลหากเป็นจริงตามเงื่อนไข

# %% [markdown]
# ####◻️ 2.5.2 if-else

# %% [markdown]
# จากข้างต้น ถ้าตรงตามเงื่อนไข ทำอะไร แต่ไม่มีบอกว่า ถ้าไม่ตรงเงื่อนไข จะให้ทำอะไรหรือเปล่า เข้าไปอีกว่า ไม่ตรง จะให้ทำอะไร เราก็จะใช้ if-else รูปแบบคำสั่ง คือ

# %% [markdown]
# ```python
# #ตัวอย่างโครงสร้าง
# if <เงื่อนไข> :
#   <คำสั่งที่ดำเนินการเมื่อเข้าตามเงื่อนไข>
# else:
#   <คำสั่งที่ดำเนินการเมื่อไม่เข้าเงื่อนไข>
# ```

# %% [markdown]
# ---

# %%
student = 79
if student == 80 :
  print("น้อง ๆ มากันครบ")
else:
  print("น้อง ๆ มากันไม่ครบ TT")

# %% [markdown]
# บรรทัดแรก student = 79 # คือการกำหนดค่าให้ student = 79
#
# บรรทัดสอง if student > 80: # การตั้งเงื่อนไขว่า มีน้อง ๆ นักเรียนเท่ากับ 80 คนหรือไม่
#
# บรรทัดสาม print(“น้อง ๆ มากันครบ”) # แสดงผลหากเป็นจริงตามเงื่อนไข
#
# บรรทัดสี่ else: # หากไม่ตรงตามเงื่อนไขจะมาใช้คำสั่งในช่องนี้
#
# บรรทัดห้า print(“น้อง ๆ มากันไม่ครบ TT”) # แสดงผลหากไม่เป็นจริงตามเงื่อนไข

# %% [markdown]
# ####◻️ 2.5.3 If-elif-else

# %% [markdown]
# ในขณะที่ด้านบน จะใส่เงื่อนไขเดียวไปเรื่อย ๆ ถ้า เงื่อนไข มีมากกว่า 1 เราใช้ if – elif จะคล้าย if- else แต่ในขณะที่ else คือการบอกว่า ถ้าไม่เข้าเงื่อนไขใน if จะให้ทำอะไร elif จะเป็นการกำหนดเงื่อนไขใหม่ไปเรื่อย ๆ If else ladder

# %% [markdown]
# ```python
# #ตัวอย่างโครงสร้าง
# if <เงื่อนไข> :
#   <คำสั่งที่ดำเนินการเมื่อเข้าตามเงื่อนไข>
# elif <เงื่อนไข> :
#   <คำสั่งที่ดำเนินการเมื่อเข้าตามเงื่อนไข2>
# else:
#   <คำสั่งที่ดำเนินการเมื่อไม่เข้าเงือนไข>
# ```

# %%
x = int(input("Enter the number: "))
if x == 0:
    print("zero")
elif x > 0:
    print("positive")
else:
    print("negative")

# %% [markdown]
# **--- สำคัญ ---**

# %% [markdown]
# Indent and colon

# %%
score = 70
if score > 60:
  print("ผ่านจ้า")
print("ไม่ผ่านน้า")

# %% [markdown]
# จะเห็นได้ว่าได้แสดงผล "ไม่ผ่านน้า" ออกมาด้วย
# เนื่องจากในภาษา Python การ **ย่อหน้า** มีความสำคัญมาก

# %% [markdown]
# **Condition Quick Challange**

# %% [markdown]
# ให้น้อง ๆ ลองสร้างโปรแกรมคำนวณเกรดจาก คะแนน ที่เป็นตัวเลขให้เป็นตัวหนังสือ เกรด A B C D และ F

# %% [markdown]
# |คะแนน |เกรด|
# |---|---|
# 80ขึ้นไป|A
# 70-79|B
# 60-69|C
# 50-59|D
# ต่ำกว่า50|F

# %%
#เขียนโค้ดโปรแกรมคำนวณเกรดตรงนี้

# %% [markdown]
# ###🟩 2.6 การทำซ้ำ (Iteration)

# %% [markdown]
# **Iteration** แปลว่า “การทำซ้ำ”  หรือ คำสั่งวนลูป เป็นคำสั่งที่ใช้ควบคุมการทำงานของโปรแกรมแบบวนซ้ำ ๆ การทำงานเดิม ๆ ตามเงื่อนไขที่กำหนด คล้าย ๆ กับคำสั่ง if แต่จะเป็นการทำคำสั่งเดิมซ้ำ ๆ จนกว่าจะตรงตามเงื่อนไข จึงจะหยุด loop
#
#
#
# *   การจะเขียน loop จำเป็นต้องรู้เงื่อนไขที่จะทำให้ loop หยุดทำงานก่อน (exit condition)
# *   การเขียน loop จำเป็นต้องเขียน exit condition ด้วยไม่อย่างงั้นจะทำให้เกิด infinite loop ซึ่งบางกรณีอาจร้ายแรงถึงขั้นคอมค้าง
# * บางโปรแกรมถูกออกเป็นมาให้ทำงานไม่มีสิ้นสุด โดยจะเป็น infinite loop แต่โปรแกรมเหล่านี้ถูกเขียนมาโดยมีการจำกัดปริมาณการใช้งาน resource เครื่องอยู่แล้ว เช่น นาฬิกา

# %% [markdown]
# **การเขียน loop มีคำสั่งหลัก ๆ อยู่ 2 คำสั่ง**

# %% [markdown]
# ####◻️ 2.6.1 While loop

# %% [markdown]
# ```python
# #ตัวอย่างโครงสร้าง
# while <ทำซ้ำจนกระทั่งไม่เข้าเงื่อนไข>:
#   <คำสั่งที่ดำเนินการเมื่อเข้าเงื่อนไข>
#
# ```

# %% [markdown]
# เป็นการวนลูปที่จะวนไปเรื่อย ๆ จนกว่าเงื่อนไขจะเป็น False เหมาะสำหรับการวนลูปที่เรายังไม่รู้จำนวนครั้งที่ต้องวนแน่ชัด

# %%
i = 1
while i < 6:
  print(i)
  i = i + 1
print("END")

# %%
teacher_list = ["Fluke", "Mee", "Flourbag"]
i=0

while i < len(teacher_list):
    print(teacher_list [i])
    i +=1

# %%
5user_input = " "
quize_score = []

while user_input != -1:
    user_input = float(input("กรุณากรอกคะแนนของท่าน => "))
    quize_score.append(user_input)

quize_score.pop()
print (quize_score)

# %% [markdown]
# ####◻️ 2.6.2 For loop

# %% [markdown]
# ```python
# #ตัวอย่างโครงสร้าง
# for <ตัวแปรที่นำมาแทนค่า> in <ช่วงของข้อมูลที่จะนำมาแทนค่า> :
#   <คำสั่งที่ดำเนินการเมื่อเข้าเงื่อนไข>
# ```

# %% [markdown]
# เป็นคำสั่งที่ใช้สำหรับวนค่าใน sequence เรียกว่า Iterating เช่น วนค่าทั้งหมดใน lists, dict, หรือ str เป็นต้น และเหมาะสำหรับการวนที่เรารู้จำนวนครั้งแน่ชัด

# %% [markdown]
# ```python
# #ตัวอย่างโครงสร้าง
# for <ตัวแปรที่นำมาแทนค่า> in range<stat,stop,step> : #โดยค่าเริ่มต้นหากแทนค่าเดียวจะเป็นค่า stop
#   <คำสั่งที่ดำเนินการเมื่อเข้าเงื่อนไข>
# ```

# %%
for i in range(6):
  print(i)

# %%
teacher_list = ["Fluke", "Mee", "Chokun"]
#loop items
for x in teacher_list:
  print(x)

# %%
kmutt_menu = { 'kaitod': 45, 'numprikkapi' : 40, 'tomyum' : 50, 'somtum' : 55}

#loop keys 
for hiwkaw in kmutt_menu:
  print(hiwkaw)

print()
#loop values
for price in kmutt_menu.values():
  print(price)

# %% [markdown]
# ####◻️ 2.6.3 Nested loop

# %% [markdown]
# เป็นการวนลูปซ้อนลูป โดยการเขียนจะมีความซับซ้อนขึ้น จำเป็นต้องคำนึงถึง exit condition ให้ดี

# %%
adj = ["small","big","tasty"]
zabder_menu = ["larbmoo","somtum", "kaiyaang"]

for x in adj:
  for y in zabder_menu:
    print(x,y)

# %% [markdown]
# ####◻️ 2.6.4 Break

# %% [markdown]
# เป็นคำสั่งที่ทำให้ออกจากลูปโดยไม่สนใจว่าเงื่อนไขต้องเป็น False

# %%
for i in range(10):
  if i > 5:
    break
  print(i)

# %% [markdown]
# ####◻️ 2.6.5 Continue

# %% [markdown]
# เป็นคำสั่งที่ทำให้ข้ามไปวนลูปครั้งต่อไปได้เลย โดยไม่ต้องทำคำสั่งให้ครบ

# %%
for i in range(10):
  if i == 5:
    continue
  print(i)

# %% [markdown]
# ###🟩 2.7 ฟังก์ชัน (Function)

# %% [markdown]
# เป็น block ของ code ที่จะรันต่อเมื่อถูกเรียกใช้เท่านั้น เราสามารถส่งข้อมูลหรือตัวแปรเข้า function ได้ โดยประโยชน์ของ function คือการลดการเขียน code ซ้ำ เมื่อต้องการใช้คำสั่งเดิม ๆ หลายรอบ เราสามารถเรียกใช้ function แทนการต้องเขียน code นั้นใหม่ทั้งหมด

# %% [markdown]
# *  Parameters คือตัวแปรของ function ที่มารับค่าที่ถูกส่งเข้ามา
# *  Arguments ค่าที่ถูกส่งเข้ามาใน function
# *  function จะ return ค่า หรือไม่ return ก็ได้
# *  หากเราไม่ return ค่า function จะ return None ให้เป็น default

# %% [markdown]
# **1.   Create function**
#
# การประกาศ function จะใช้คำสั่ง def นำหน้า ตามด้วยชื่อของ function และ ตามด้วย parameters ที่อยู่ในวงเล็บ ( ) ตามด้วย colon ( : ) จากนั้นคำสั่งที่อยู่ภายใน function จะต้องมี indent เข้ามา 1 Tab เป็นการบ่งบอกว่าเป็นคำสั่งภายใต้ function นี้

# %% [markdown]
# **Example1.1  Create function**

# %%
def Seven11():

# %%
def my_function_1():
  print("Hello from a function")

# %%
def my_function_2(name):
  print("Hello!,",name)

# %%
def catsleep():
        print("           __..--''``---....___   _..._    __")
        print(" /// //_.-'    .-/"";  `        ``<._  ``.''_ `. / // /")
        print("///_.-' _..--.'_    \                    `( ) ) // //")
        print("/ (_..-' // (< _     ;_..__               ; `' / ///")
        print(" / // // //  `-._,_)' // / ``--...____..-' /// / //")

# %%
def my_fuction_3():
  return "Hello!,"

# %% [markdown]
# **2.   Calling function**
#
# การเรียกใช้ function จะใช้ชื่อของ function โดยลักษณะจะคล้ายกับการเรียกคำสั่ง print หรือ type จากนั้นให้ใส่ค่าที่ต้องการส่งเข้า function ไว้ในวงเล็บด้านหลังชื่อ function หาก function มีการ return ค่า เราสามารถนำตัวแปรมาเก็บค่าที่ return ออกมาได้ หรือจะ print ออกไปเลยก็ได้เช่นกัน

# %% [markdown]
# **Example 2.1 Calling function**

# %%
my_function_1()

# %%
my_function_2("Kid")

# %%
catsleep()

# %%
my_fuction_3()

# %% [markdown]
# **Example 2.2 function of f given that f(x) = 5x + 3**

# %%
#using function

def f(x):
  return (5*x) + 3

print(f(5))
print(f(10))
print(f(2))
print(f(99))

# %%
#not using function

print((5*5) + 3)
print((5*10) + 3)
print((5*2) + 3)
print((5*99) + 3)

# %% [markdown]
# **Function Quick Challange**

# %% [markdown]
# ให้น้อง ๆ สร้างฟังก์ชันรูปไข่จากฟังก์ชันสองส่วน คือ ส่วนบน (Top of egg) และส่วนล่าง (Bottom of egg)

# %% [markdown]
# **Top of egg**

# %%
#เขียนโค้ด Top of egg function ตรงนี้

# %%
#Answer Key
def top():
    print("  ______")
    print(" /      \\")
    print("/        \\")

# %% [markdown]
# **Bottom of egg**

# %%
#เขียนโค้ด Bottom of egg function ตรงนี้

# %%
#Answer Key
def bottom():
    print("\        /")
    print(" \______/")

# %%
top()

# %%
bottom()

# %% [markdown]
# **Build egg with two function**

# %%
#รวมสอง function ไว่ใน หนึ่ง function
def egg():

# %%
#Answer Key
def egg():
    top()
    bottom()

# %%
#เรียกใช้ function egg()
egg()

# %% [markdown]
# ###🟩 2.8 ไลบรารี่ (Library)

# %% [markdown]
# เป็นเสมือนโปรแกรมสำเร็จรูปที่เก็บฟังก์ชันการทำงานที่เฉพาะทาง โดยประโยชน์ของ Library สำเร็จรูปที่มากับโปรแกรมนั้น คือ ผู้ใช้งานไม่จำเป็นที่จะต้องสร้าง Library ขึ้นมาใหม่เองทั้งหมด แต่สามารถนำ Library ที่ได้มีการพัฒนาไว้อยู่แล้วมาใช้งานได้เลย

# %% [markdown]
# **Import statement**

# %% [markdown]
# สามารถใช้ทุกอย่างจาก Library ที่นำเข้ามาได้ทั้งหมด

# %%
import random

# %% [markdown]
# **From statement**

# %% [markdown]
# สามารถใช้ได้แค่ fuction(s) ที่นำเข้ามาจาก Library นั้น

# %%
from random import randint, choice

# %% [markdown]
# ####◻️ 2.8.1 Numpy

# %% [markdown]
# **Numpy**
#
# *   เป็นคลังคำสั่งที่เกี่ยวกับการคำนวณทางวิทยาศาสตร์ โดยมีที่เก็บข้อมูลที่เรียกว่า อาเรย์ n มิติ (ndarray) มีไว้เก็บข้อมูลเพื่อการประมวลผลที่มีประสิทธิภาพมาก ๆ
# *   อาเรย์มีลักษณะคล้ายลิสต์ (Lists) แต่สร้างแล้วเปลี่ยนขนาดไม่ได้
# * ค่าในอาเรย์ทุกช่องต้องเป็นประเภทเดียวกันทั้งหมด เช่น เป็น int ทุกช่อง หรือ float ทุกช่อง (ผสมกันไม่ได้ ถ้าเป็นลิสต์ผสมได้)
# *เราสร้าง เวกเตอร์ ได้ด้วยอาเรย์ 1 มิติ และสร้าง เมทริกซ์ ได้ด้วยอาเรย์ 2 มิติ
# เวลาจะใช้งาน numpy ก็สามารถ import เข้ามาใช้งานได้เหมือนตัวอย่างด้านล่างนี้เลย

# %%
import numpy as np 
a = np.array([1,2,3])
print(a)
print(type(a))

# %% [markdown]
# ####◻️ 2.8.2 Math

# %% [markdown]
# **Math**
#
# *   เป็นคลังคำสั่งที่เกี่ยวกับการคำนวณทางคณิตศาสตร์ต่างๆ
#
# *   เราสามารถคำนวณได้หลากหลายอย่างเช่น ตรีโกณมิติ, ลอการิทึม เป็นต้น

# %%
import math
b =math.sqrt(100)
print("Square root value of 100 is",b)

# %% [markdown]
# ## 📊 บทที่3 : การจัดการข้อมูล และ นำเสนอข้อมูลเบื้องต้น

# %% [markdown]
# ###🟦 3.1 กระบวนการจัดการข้อมูล

# %% [markdown]
# **การจัดการข้อมูล** หมายถึงกระบวนการเปลี่ยนรูป ทำความสะอาด  และจัดระเบียบข้อมูลเพื่อให้เหมาะสมสำหรับการวิเคราะห์และการสร้างแบบจำลอง ซึ่งอาจเกี่ยวข้องกับงานต่าง ๆ เช่น การรวมชุดข้อมูล การเติมค่าที่ขาดหายไป การแปลงค่าตัวแปร การรวมข้อมูล และอื่น ๆ เป้าหมายของการจัดการข้อมูลคือการเตรียมข้อมูลสำหรับการวิเคราะห์ในลักษณะที่ทำให้มั่นใจว่าถูกต้อง สอดคล้อง และเชื่อถือได้ เพื่อให้ข้อมูลเชิงลึกและข้อสรุปที่ได้จากข้อมูลมีความน่าเชื่อถือ

# %% [markdown]
# ###🟦 3.2 ทำความรู้จัก Pandas

# %% [markdown]
# **pandas** คือ หนึ่งใน Library สำคัญของภาษา Python เริ่มพัฒนาโดย Wes McKinney นักพัฒนาซอฟต์แวร์ชาวอเมริกัน โดยที่ pandas มาจากคำว่า Panel Data (ชุดข้อมูลหลายมิติ) มีจุดเด่นด้านการวิเคราะห์ข้อมูล (Data Analysis) การทำความสะอาด (Data Cleaning) ผ่านกระบวนการจัดการข้อมูล (Data manipulation)  ซึ่งเป็นกระบวนการที่สำคัญมากในการทำงานกับข้อมูล ปัจจุบัน pandas เป็น open source ให้ทุกคนสามารถใช้ได้โดยไม่มีค่าใช้จ่าย
#
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTkKmkBqviJKR3yCj5F251eRodlrKmubG6ey7pJMGGLMs2CF23gBT_4QevLGRVUjcSXSkQ&usqp=CAU)

# %% [markdown]
# ###🟦 3.3 การเรียกใช้ pandas

# %% [markdown]
# โดยปกติแล้ว หากใช้งานผ่านทาง Google Colab หรือ Jupyter Notebook จะมี Library พื้นฐานเกี่ยวกับการจัดข้อมูลติดตั้งมาเรียบร้อยแล้ว ดังนั้นจึงสามารถใช้คำสั่ง import เรียก pandas เข้ามาใช้งานได้ทันที

# %% [markdown]
# เพื่อความสะดวกในการเรียกใช้คำสั่ง เราจะนำเข้ามาในชื่อ pd  ซึ่งย่อมาจาก pandas นั่นเอง

# %%
import pandas as pd

# %% [markdown]
# สามารถตรวจสอบเวอร์ชั่น Pandas ที่เราใช้ ผ่านคำสั่ง `pd.__version__`

# %%
pd.__version__

# %% [markdown]
# ###🟦 3.4 ประเภทข้อมูลใน Pandas

# %% [markdown]
# ####◻️ Series

# %% [markdown]
# **Series**  คือ ประเภทข้อมูลแบบหนึ่ง ทำหน้าที่เก็บข้อมูลประเภทต่าง ๆ  คล้ายกับลิสต์ขนาดหนึ่งมิติ ในภาษา Python ข้อแตกต่างสำคัญคือ ระบบในการกำกับตำแหน่ง (idex) ในขณะที่ลิสต์ใช้ตัวเลขกำกับเริ่มต้นที่ศูนย์ และ ไล่เรียงไปเรื่อย ๆ ตามลำดับ Series จะสามารถกำหนดตำแหน่ง (index) ให้กับข้อมูลได้

# %% [markdown]
# > ในตัวอย่างนี้เราจะมาลองเก็บส่วนสูงของเพื่อน ๆ 5 คน กัน
# โดยเพื่อน ๆ มีความสูงตามลำดับดังนี้ 155,182, 170, 163 และ 175

# %%
height_list = [155,172,170,163,175]
height_list

# %%
pd.Series(height_list)

# %% [markdown]
# > ไม่นะ! โรงเรียนที่เพื่อน ๆ 5 คนนี้แปลกมาก แทนที่จะแทนรหัสนักเรียน ด้วยเลขที่ แต่กลับแทนด้วยอักษร A,B,C ... ตามลำดับแทน
#
# > ถึงเวลาที่เราจะต้องมาลองแก้ index ใน Serires กันแล้ว!

# %%
pd.Series(height_list, index=['A','B','C','D','E'])

# %% [markdown]
# ####◻️ DataFrame

# %% [markdown]
# **DataFrame** คือ โครงสร้างข้อมูลแบบสองมิติ ที่ประกอบขึ้นจากข้อมูลประเภท Series ซึ่งโครงสร้างในลักษณะการเก็บและจัดการข้อมูลในแบบตาราง

# %%
#สร้าง List ออกมาสอง List 
staff = ['พี่โต', 'พี่หลาม', 'พี่คัสซึยะ', 'พี่แดเนียล']
age = ["35", "40", "33", "25"]
hobby = ["เต้น","ออกกำลังกาย","ปั่นจักรยาน","ขับรภ"]
salrary = [34000,25000,31500,50000]

#สร้าง Series จาก List
staff_series = pd.Series(staff)
age_series = pd.Series(age)
hobby_series = pd.Series(hobby)
salrary_series = pd.Series(salrary)

#สร้าง Dictionary ที่เก็บข้อมูล Series ไว้
frame = { 'name': staff_series, 'age': age_series,"hobby":hobby_series, "salrary": salrary_series}
#สร้าง DataFrame ด้วย Dictionary 
result = pd.DataFrame(frame)
result

# %% [markdown]
# ###🟦 3.5 การนำเข้าข้อมูล

# %% [markdown]
# #### 3.5.1 การอ่านข้อมูลตามประเภทไฟล์ข้อมูล

# %% [markdown]
# ในส่วนนี้จะมุ่งเน้นถึงการนำเข้าข้อมูลมที่ถูกบันทึกในรูปแบบต่าง ๆ ให้สามารถเข้าถึงได้ในรูปแบบ DataFrame เพื่อประโยชน์ต่อการวิเคราะห์ข้อมูลต่อไป

# %% [markdown]
# | ชนิดไฟล์ข้อมูล  | นามสกุล  |  คำอธิบาย |คำสั่งที่ใช้ในการอ่านข้อมูล
# |---|---|---|---|
# | CSV | .csv |<br>Comma-Separated Values (CSV)<br>  คือ ไฟล์ค่าที่มีเครื่องหมายจุลภาค (comma) คั่นในแต่ละบรรทัด<br><br> |      `pd.read_csv()`
# |  JSON | .json  |<br>JavaScript Object Notation (JSON)<br> คือข้อมูลรูปแบบ text ที่มีรูปแบบที่จะเก็บข้อมูลแบบ key, value <br>โดยการเขียนข้อมูลชนิด JSON มีรูปแบบคือ ชื่อฟิลด์ครอบด้วยเครื่องหมาย <br>“ (double quote), เครื่องหมาย : (colon), value แล้วครอบทั้งหมดด้วยเครื่องหมายปีกกา <br><br>|   `pd.read_json()`
# |  Excel |  .xlsx |<br>Microsoft Excel Open XML Spreadsheet (XLSX)<br>  คือไฟล์สำหรับบันทึกข้อมูลในรูปแบบ ตารางทำงาน (Spreadsheet)<br> จากโปรแกรม Microsoft Excel<br><br> | `pd.read_excel()`|

# %% [markdown]
# #### 3.5.2 การนำเข้าข้อมูลจากแหล่งจากเก็บข้อมูลออนไลน์

# %% [markdown]
# จากคำสั่งต่าง ๆ ในหัวข้อ 3.5.1 นอกเหนือจากที่เราสามารถนำเข้าข้อมูลจากแหล่งเก็บข้อมูลภายในคอมพิวเตอร์ของเราเองแล้ว เราสามารถ นำเข้าข้อมูลจากแหล่งเก็บข้อมูลออนไลน์ ผ่าน ยูอาร์แอล (Uniform Resource Locator : URL) โดยใช้คำสั่งเดียวกัน

# %%
#ฟังก์ชัน สำหรับการปรับURL Google Drive สำหรับ share ให้เป็นสำหรับ download 
#(สำหรับในกรณีที่นำเข้าข้อมูลมาจาก Google Drive)
def format_drive_url(drive_url):
  drive_url='https://drive.google.com/uc?id=' + drive_url.split('/')[-2]
  return drive_url

# %%
#นำเข้า url ไฟล์ข้อมูล จาก Github
csv_url = "https://github.com/ChotanansubSoph/COMCAMP-COM104/blob/main/Dataset/com104_unit3-5.csv?raw=true"
json_url = "https://github.com/ChotanansubSoph/COMCAMP-COM104/blob/main/Dataset/com104_unit3-5.json?raw=true"
excel_url = "https://github.com/ChotanansubSoph/COMCAMP-COM104/blob/main/Dataset/com104_unit3-5.xlsx?raw=true"

# %%
pd.read_csv(csv_url)

# %%
pd.read_json(json_url)

# %%
pd.read_excel(excel_url)

# %% [markdown]
# ###🟦 3.6 การเปิดดูข้อมูล

# %%
#นำเข้าข้อมูลสำหรับการสาธิต
customer_data01_url = "https://github.com/ChotanansubSoph/COMCAMP-COM104/blob/main/Dataset/com104_LectureData_customer_01.csv?raw=true"
customer_data02_url = "https://github.com/ChotanansubSoph/COMCAMP-COM104/blob/main/Dataset/com104_LectureData_customer_02.csv?raw=true"
customer_data03_url = "https://github.com/ChotanansubSoph/COMCAMP-COM104/blob/main/Dataset/com104_LectureData_customer_03.csv?raw=true"

CUSTOMER_DATA = pd.read_csv(customer_data01_url) 
EXTENED_CUSTOMER = pd.read_csv(customer_data02_url) 
EXTENED_FIELD = pd.read_csv(customer_data03_url)

# %% [markdown]
# ####◻️ 3.6.1 การเปิดดูข้อมูลภาพรวม

# %%
CUSTOMER_DATA

# %% [markdown]
# ####◻️ 3.6.2 การเปิดดูข้อมูลส่วนต้น (Head)

# %%
CUSTOMER_DATA.head()

# %% [markdown]
# ####◻️ 3.6.3 การเปิดดูข้อมูลส่วนท้าย (Tial)

# %%
CUSTOMER_DATA.tail()

# %% [markdown]
# ####◻️ 3.6.4 การเปิดดูข้อมูลลำดับ (Index)

# %%
CUSTOMER_DATA.index

# %% [markdown]
# ####◻️ 3.6.5 การเปิดดูรายการคอลัมน์ (Column)

# %%
CUSTOMER_DATA.columns

# %% [markdown]
# ####◻️ 3.6.6 ดูสรุปข้อมูลอย่างง่าย

# %% [markdown]
# สามารถทำได้โดยใช้ Method ชื่อว่า `describe()`

# %% [markdown]
# |ค่า| คำอธิบาย |
# |---|---|
# |count| จำนวนข้อมูล|
# |mean| ค่าเฉลี่ย|
# |std| [ค่าเบี่ยงเบนมาตรฐาน (Standard Deviation)](https://th.wikipedia.org/wiki/%E0%B8%84%E0%B9%88%E0%B8%B2%E0%B9%80%E0%B8%9A%E0%B8%B5%E0%B9%88%E0%B8%A2%E0%B8%87%E0%B9%80%E0%B8%9A%E0%B8%99%E0%B8%A1%E0%B8%B2%E0%B8%95%E0%B8%A3%E0%B8%90%E0%B8%B2%E0%B8%99)|
# |%| ค่าของข้อมูล ณ [เปอร์เซ็นต์ไทล์(Percentile)](https://www.opendurian.com/learn/percentile/) ที่กำหนด<br><br>ค่าเริ่มต้นได้แก่ 25%, 50% และ 75 % ตามลำดับ|
# |min| ค่าต่ำสุด|
# |max| ค่าสูงสุด|

# %%
CUSTOMER_DATA.describe()

# %% [markdown]
# ####◻️ 3.6.7 การเปิดดูข้อมูลผ่านการเรียงลำดับ

# %%
#น้อย -> มาก
CUSTOMER_DATA.sort_values(by="point")

# %%
#มาก -> น้อย 
CUSTOMER_DATA.sort_values(by="point", ascending=False)

# %% [markdown]
# ####◻️ 3.6.8 การจำแนกข้อมูล และ กับกำกับจำนวน

# %%
CUSTOMER_DATA['job'].value_counts()

# %% [markdown]
# ###🟦 3.7 การเลือกข้อมูล (Selection)

# %% [markdown]
# ####◻️ 3.7.1 เลือกจากข้อมูลจากคอลัมน์ (Column head)

# %%
CUSTOMER_DATA['name']

# %%
CUSTOMER_DATA[['name','job']]

# %% [markdown]
# ####◻️ 3.7.2 เลือกข้อมูลจากตำแหน่ง (Position)

# %% [markdown]
# ###### **การเลือกผ่านคำสั่ง** `.loc()`

# %% [markdown]
# * สาระน่ารู้:  `.loc`  ย่อมาจาก "location" หรือ "location-based indexing"

# %%
CUSTOMER_DATA.loc[[0]]

# %%
CUSTOMER_DATA.loc[[0,1,2]]

# %%
CUSTOMER_DATA.loc[1:100]

# %% [markdown]
# ##### **การเลือกผ่านคำสั่ง** `.iloc()`

# %% [markdown]
# * `.iloc`  ย่อมาจาก "integer location-based indexing"

# %%
CUSTOMER_DATA.iloc[[0]]

# %%
CUSTOMER_DATA.iloc[0:10]

# %% [markdown]
# ##### **การเลือกผ่านเงื่อนไข (Bolean Indexing)**

# %%
CUSTOMER_DATA[CUSTOMER_DATA["point"]>15000]

# %%
CUSTOMER_DATA[CUSTOMER_DATA["gender"] == "เพศชาย"]

# %% [markdown]
# ##### **การประยุกต์ iloc สำหรับการเลือกหลายหลายเงื่อนไข (Multiple Condition)**

# %% [markdown]
# **ตัวอย่างปัญหา:** จงแสดงตารางข้อมูลรายบุคคล โดยที่ บุคคลนั้น เป็นเพศชาย "และ" คะแนนสะสมมากกว่า 15,000 คะแนน

# %% [markdown]
# พิจารณาตามหลักตรรกศาสตร์ได้ว่า
# * **ประพจน์ที่ 1 :** เป็นเพศชาย
# * **ตัวดำเนินการ :** และ (∧)
# * **ประพจน์ที่ 2 :** คะแนนมากกว่า 15,000 คะแนน

# %%
CUSTOMER_DATA.loc[(CUSTOMER_DATA['gender']=="เพศชาย") & (CUSTOMER_DATA['point']>15000)]

# %% [markdown]
# **ตัวอย่างปัญหา:** แสดงตารางข้อมูลรายบุคคล โดยที่ บุคคลนั้น อยู่จังหวัดพะเยา "หรือ" อาชีพเป็นนักการศึกษา

# %% [markdown]
# พิจารณาตามหลักตรรกศาสตร์ได้ว่า
# * **ประพจน์ที่ 1 :** อยู่จังหวัดพะเยา
# * **ตัวดำเนินการ :** หรือ (∨)
# * **ประพจน์ที่ 2 :** อาชีพเป็นนักการศึกษา

# %%
CUSTOMER_DATA.loc[(CUSTOMER_DATA['province']=="จังหวัดพะเยา") | (CUSTOMER_DATA['job']=="นักการศึกษา")]

# %% [markdown]
# Quick

# %% [markdown]
# ###🟦 3.8 การรวมข้อมูล (Data Integration)

# %% [markdown]
# ####◻️ 3.8.1 การเชื่อมข้อมูล (Concatenate)

# %%
CUSTOMER_DATA #ข้อมูลตั้งต้น

# %%
EXTENED_CUSTOMER #ข้อมูลที่ต้องการเชื่อม

# %%
#เชื่อมต่อข้อมูลทั้งสองเข้าด้วยกัน 
pd.concat([CUSTOMER_DATA,EXTENED_CUSTOMER])

# %%
#เพิ่ม ignore_index=True เพื่อ reset index ใหม่อีกครั้ง 
CONCATED_DATA = pd.concat([CUSTOMER_DATA,EXTENED_CUSTOMER], ignore_index=True)
CONCATED_DATA

# %% [markdown]
# ####◻️ 3.8.2 การผสานข้อมูล (Merge)

# %% [markdown]
# นำเข้าข้อมูลสาธิตใหม่

# %%
EXTENED_FIELD

# %% [markdown]
# ข้อสังเกตข้อมูลใหม่

# %% [markdown]
# *   คอลัมน์ "name" มีข้อมูลเหมือนกับ ข้อมูลดั้งเดิมของเรา ส่วน คอลัมน์อื่นๆเป็นข้อมูลใหม่
# *   ข้อมูลในคอลัมน์ "SIM_Package" มีอักขระที่ไม่จำเป็น ติดเข้ามา เช่น "$"
# * ข้อมูลในคอลัมน์สุดท้ายมีปัญหา และ ข้อมูลทั้งหมดประกอบไปด้วย `NaN`

# %%
#ทำการผสานข้อมุลเข้าด้วยกัน
MERGED_DATA = pd.merge(CONCATED_DATA,EXTENED_FIELD)
MERGED_DATA

# %% [markdown]
# ###🟦 3.9 ลบข้อมูล (Drop)

# %% [markdown]
# ##### 3.9.1 การลบข้อมูลตามแถว (Row)

# %%
MERGED_DATA.drop([0,1])

# %% [markdown]
# ##### 3.9.2 การลบข้อมูลตามแนวสดมภ์ (Column)

# %%
MERGED_DATA.drop(["name","gender"], axis=1)

# %%
MERGED_DATA.drop(columns = ["age","job"])

# %%
MERGED_DATA.drop(MERGED_DATA.columns[2:],axis=1)

# %% [markdown]
# การลบข้อมูลตามเงื่อนไข

# %% [markdown]
# สังเกตว่าข้อมูลในคอลัมน์สุดท้ายมีปัญหา เราสามารถลบออกได้ ดังนี้

# %%
DROPPED_DATA = MERGED_DATA.drop(columns = ["ERROR"])
DROPPED_DATA

# %% [markdown]
# ###🟦 3.10 ตัวดำเนินการ (Operation)

# %% [markdown]
# ####◻️ 3.10.1 การนำฟังก์ชันมาใช้ (Apply)

# %% [markdown]
# เป็นการนำฟังก์ชันมาดำเนินการเพื่อแก้ไขข้อมูลของเรา

# %%
DROPPED_DATA['job']

# %%
def add_job(job):
  return "อาชีพ"+job

DROPPED_DATA['job'].apply(lambda x: add_job(x))

# %%
DROPPED_DATA['job'].apply(lambda x: "อาชีพ"+x)

# %% [markdown]
# การประยุกต์ใช้กับการทำความสะอาดข้อมูลในคอลัมน์ SIM_Package

# %%
CLEARN_DATA = DROPPED_DATA.copy()

# %%
def clean_text(text):
  text = text.replace('$','') #แทนที่ อักษร '$' ด้วย '' (แทนที่ด้วยสตริงว่างเปล่า)
  text = text.replace('?','') #แทนที่ อักษร '?' ด้วย '' (แทนที่ด้วยสตริงว่างเปล่า)
  return text

CLEARN_DATA['SIM_Package'] = DROPPED_DATA['SIM_Package'].apply(lambda x: clean_text(x))
CLEARN_DATA

# %% [markdown]
# ####◻️ 3.10.2 ตัวดำเนินการทางสถิติพื้นฐาน

# %% [markdown]
# ##### การหาค่าเฉลี่ย

# %%
CLEARN_DATA.mean()

# %% [markdown]
# ##### การนับปริมาณข้อมูล

# %%
CLEARN_DATA['province'].value_counts()

# %%
CLEARN_DATA['Usage'].value_counts()

# %%
CLEARN_DATA.to_csv("test.csv",index=False)

# %% [markdown]
# ### 🟦 3.11 การส่งออกข้อมูล (Exporting)

# %% [markdown]
# การส่งออกข้อมูลในรูปแบบ CSV

# %%
CLEARN_DATA.to_csv("completed_customer_data.csv")

# %% [markdown]
# ###🟦 3.12  แนะนำไลบรารี่สำหรับการนำเสนอข้อมูล (Visualization)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


plt.close("all")

# %% [markdown]
# #### ◻️ 3.12.1 Numpy

# %% [markdown]
# NumPy คือ ไลบรารี่ที่ใช้สำหรับการทำงานกับข้อมูลที่มีลักษณะเป็นเมทริกซ์และอาร์เรย์ (arrays) ต่าง ๆ ซึ่งเป็นสิ่งจำเป็นสำหรับการวิเคราะห์ข้อมูลซึ่งต้องมีการจัดการกับข้อมูลในลักษณะเหล่านี้อยู่เสมอ โดย NumPy จะมีฟังก์ชันและเครื่องมือต่าง ๆ ที่ช่วยให้ผู้ใช้งานสามารถดำเนินการทางคณิตศาสตร์กับเมทริกซ์และอาร์เรย์ได้อย่างสะดวกและรวดเร็วมากขึ้น เช่น การหาค่าเฉลี่ย การหาค่าสูงสุด การหาค่าต่ำสุด การหาค่ามัธยฐาน การคำนวณผลรวม การคูณ การแยกเมทริกซ์ และอื่น ๆ อีกมากมาย

# %% [markdown]
# **NumPy Arrays** มีประโยชน์อย่างไร? เมื่อเปรียบเทียบกับ Python Lists
#
# * 🚀 สามารถคำนวณและดำเนินการทางตรรกะใน Matrix , Array หลายมิติ และ Array ได้อย่างรวดเร็ว มากกว่า Python Lists
# * 📦 ประหยัด หน่วยความจำ (memory) ได้มากกว่าใช้ Python Lists

# %%
np.array([[1,0,0], [0,1,0], [0,0,1]])

# %% [markdown]
# **เกร็ดความรู้เสริม**💡 ตัวอย่างการใช้งานตัวดำเนินการใน numpy array ที่เกี่ยวข้องกับเมทริกซ์

# %%
# สร้างเมทริกซ์ ขนาด 2x2 มิติ
matrix_a = np.array([[1, 2], [3, 4]])
matrix_b = np.array([[5, 6], [7, 8]])
print("เมทริกซ์ A \n",matrix_a,"\n")
print("เมทริกซ์ B \n",matrix_b,"\n")

# สร้างเมทริกซ์ ขนาด 1x2 มิติ
matrix_c = np.array([9, 10])
print("เมทริกซ์ C \n",matrix_c,"\n")

# การคูณเมทริกซ์
result1 = np.dot(matrix_a, matrix_b)
print("ผลลัพธ์การคูณเมทริกซ์ A และ B  \n",result1,"\n")

# การคูณเมทริกซ์ที่มิติแตกต่างกัน
result2 = np.dot(matrix_a, matrix_c)
print("ผลลัพธ์การคูณเมทริกซ์ A และ C  \n",result1,"\n")

# การคูณในระดับสมาชิก (element-wise multiplication)
result3 = matrix_a * matrix_b
print("ผลลัพธ์การการคูณในระดับสมาชิก (element-wise multiplication) A และ B  \n",result3,"\n")

# การหาดีเทอร์มิแนนต์ 
determinant = np.linalg.det(matrix_a)
print("ผลลัพธ์การหาดีเทอร์มิแนนต์ เมทริกซ์ A \n",determinant,"\n")

# การหาเมทริกซ์ผกผัน 
inverse_matrix_a = np.linalg.inv(matrix_a)
print("ผลลัพธ์การหาเมทริกซ์ผกผัน ของเมทริกซ์ A \n",inverse_matrix_a,"\n")

# %% [markdown]
# #### ◻️ 3.12.2 Matplotlib

# %% [markdown]
# Matplotlib เป็นไลบรารี่ Python ที่ใช้สำหรับการพล็อตกราฟและภาพแบบต่าง ๆ ในการวิเคราะห์ข้อมูล โดยสามารถสร้างกราฟที่หลากหลายรูปแบบได้ เช่น กราฟเส้น (line plot) กราฟแท่ง (bar plot) กราฟแฟ้ม (scatter plot) และอื่น ๆ
#
# Matplotlib เป็นไลบรารี่ที่มีความนิยมในการพล็อตกราฟใน Python เนื่องจากมีความสามารถในการปรับแต่งรายละเอียดกราฟได้หลากหลาย ทำให้ผู้ใช้สามารถปรับแต่งกราฟให้เหมาะสมกับการนำเสนอข้อมูลได้อย่างเหมาะสม นอกจากนี้ Matplotlib ยังสามารถใช้งานร่วมกับไลบรารี่ Python อื่น ๆ เช่น NumPy, Pandas, และ SciPy เพื่อการวิเคราะห์ข้อมูลที่มีความซับซ้อนขึ้นได้

# %%
# สร้างตัวอย่างชุดข้อมูลสำหรับการพล็อตกราฟ
x = np.arange(0, 10, 0.1)
y = np.sin(x)

# สร้างตัวแปรเก็บข้อมูลภาพ และ แกน
fig, ax = plt.subplots()

# พล็อตข้อมูลลงบนแกน
ax.plot(x, y)

# ตั้งชื่อหัวข้อกราฟ และ ชื่อกำกับแกน x และ y
ax.set_title('Sinusoidal Wave')
ax.set_xlabel('X')
ax.set_ylabel('Y')

# แสดงกราฟ
plt.show()

# %% [markdown]
# ###🟦 3.13 การนำเสนอแผนภูมิ (Chart Visualization)

# %%
CLEARN_DATA

# %%
CLEARN_DATA['age']

# %%
plt.hist(CLEARN_DATA['point'],bins=200)
plt.show()

# %%
plt.hist(CLEARN_DATA['age'],bins=200)
plt.show()

# %%
usage_label = list(CLEARN_DATA['Usage'].value_counts().keys())
usage_label

# %%
usage_num = list(CLEARN_DATA['Usage'].value_counts())
usage_num

# %%
#กำหนดขนาดกรอบรูปสำหรับการนำเสนอข้อมูล
fig = plt.figure(figsize = (10, 5))
  
plt.bar(
    usage_label, 
    usage_num, 
    color ='orange',
    width = 0.4)

plt.xlabel("Content")                   #ตั้งชื่อแกน X
plt.ylabel("Number of customers")       #ตั้งชื่อแกน Y
plt.title("Online Content Consumption") #ตั้งชื่อหัวข้อ
plt.show()                              #แสดงกราฟ

# %%
ax1 = CLEARN_DATA.plot.scatter(x='age',y='point')

# %%
sns.lmplot(x='age', y='point', data=CLEARN_DATA, hue='Usage', fit_reg=False)
plt.show()

# %% [markdown]
# ## 📚 แหล่งอ้างอิง (Reference)

# %% [markdown]
# ####  บทที่1: ✍🏻 ก้าวแรกสู่การวิเคราะห์ข้อมูล

# %% [markdown]
# *   Lin, H., & Li, M. (2022). Introduction to Data Science. Scientistcafe.Retrieved February 1, 2023, from https://scientistcafe.com/ids/index.html#preface

# %% [markdown]
# ####  บทที่2: 🧑🏻‍💻 การเขียนโปรแกรมด้วยภาษา Python เบื้องต้น

# %% [markdown]
# * Python Software Foundation (2023). Python 3.11.2 documentation. Retrieved February 20, 2023, from https://docs.python.org/3/

# %% [markdown]
# #### บทที่3: 📊 การจัดการข้อมูล และ นำเสนอข้อมูลเบื้องต้น

# %% [markdown]
# *  NumFOCUS, Inc. (n.d.). 10 minutes to pandas. Pandas.Pydata. Retrieved February 2, 2023, from https://pandas.pydata.org/docs/user_guide/10min.html
# *   Refsnes Data (n.d.). Pandas Tutorial. W3schools. Retrieved February 4, 2023, from https://www.w3schools.com/python/pandas/default.asp
#
# * phpBB (n.d.).NumPy คืออะไร.Retrieved February 6, 2023.https://www.mindphp.com/developer/tips-python/8492-what-is-the-numpy.html
