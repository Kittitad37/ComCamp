# %% [markdown]
# # ⚙️ แบบฝึกปฏิบัติการ (Workshop)  (ส่วนที่ 1/2) <br>
# ### การเขียนโปรแกรมด้วยภาษา Python เบื้องต้น  <br>  COM104: Data Analytics and Visualization with Python 🐍 💻

# %% [markdown]
# ## ℹ️ เกี่ยวกับ Notebook นี้

# %% [markdown]
# > Notenook นี้จัดทำขึ้นเพื่อประกอบการเรียนการสอนในรายวิชา COM104: การวิเคราะห์ข้อมูล และ นำเสนอข้อมูลเบื้องต้นด้วย การเขียนโปรแกรมภาษาไพธอน (Data Analytics and Visualization with Python)
#
# 🚀 ภายใต้โครงการอบรมเชิงปฏิบัติการ [Comcamp ครั้งที่ 34](https://www.facebook.com/KMUTTcomcamp) ระหว่างวันที่ 9-13 เมษายน 2566
#
# ⚙️ ณ ภาควิชาวิศวกรรมคอมพิวเตอร์ คณะวิศวกรรมศาสตร์ มหาวิทยาลัยเทคโนโลยีพระจอมเกล้าธนบุรี
#
#
# ---

# %% [markdown]
# ### 📥 จัดเตรียม Library และ ข้อมูล ประกอบการสอน

# %% [markdown]
# รันเซลล์นี้เพื่อ download และ ติดตั้ง library

# %%
from IPython.display import clear_output 
#📚 Download & Install Library 
# !pip install -U pip --quiet
# !pip install -U datascience ipytest rich --quiet
clear_output()

#🤔 ✅ ❌ Function Tester (Grader) 
import ipytest
from pytest import approx
ipytest.autoconfig()

print(f"|{'#'*32}|\n|{'<'*10} ติดตั้งสำเร็จ! {'>'*10}|\n|{'#'*32}|")
# Out:
# |################################|
# |<<<<<<<<<< ติดตั้งสำเร็จ! >>>>>>>>>>|
# |################################|

# %% [markdown]
# ---
# ---
# ---
# ---

# %% [markdown]
# ## ส่วนที่1: การเขียนโปรแกรมด้วยภาษา Python 🐍

# %% [markdown]
# ###**ตัวอย่างโจทย์ที่ 1** (สาธิตกรณี คำตอบถูก ✅)

# %% [markdown]
# ####**🤯 โจทย์ปัญหา**
# กำหนดให้ฟังก์ชัน `add_number` เป็นฟังก์ชันสำหรับการบวกเลขจำนวนเต็มสองจำนวน
#
# จงเขียนโปรแกรมเพื่อทำให้ฟังก์ชันทำงานได้อย่างสมูบรณ์
#
# ---
#
# ####**✍🏻 ข้อมูลนำเข้า (Input)**
# * `num1`: เลขจำนวนเต็มที่หนึ่ง
# * `num2`: เลขจำนวนเต็มที่สอง
#
# ---
#
# ####**👀 ข้อมูลส่งออก (Output)**
# * `result`: จำนวนเต็มซึ่งเป็นผลลัพธ์จากการบวกเลข

# %% [markdown]
# ####**🧑🏻‍💻 เขียนโค้ดคำตอบ**

# %%
def add_number(num1: int, num2: int) -> int:
  #🚀การประกาศตัวแปรเริ่มต้นสำหรับเก็บคำตอบ (ไม่ต้องแก้ไขส่วนนี้)
  result = 0

  #เขียนโค้ดคำตอบของน้องๆด้านล่างข้อความนี้ 🙋🏻🙋🏻🙋🏻
  result = num1 + num2 

  return result

# %% [markdown]
# ####**👾 Playground**

# %%
#ลองเขียนโค้ดเล่นตรงนี้ได้น้า

# %% [markdown]
# ####**🔎 ตรวจสอบผลลัพธ์การทำงาน**

# %%
# %%ipytest -qqs
# #รันเซลล์นี้เพื่อตรวจคำตอบ
# def test_plus_number():
#     assert add_number(num1=5, num2=5) == approx(10)
#     assert add_number(num1=10, num2=5) == approx(15)
#     assert add_number(num1=20, num2=3) == approx(23)
#     assert add_number(num1=11, num2=4) == approx(15)
#     assert add_number(num1=200, num2=100) == approx(300)
#     print("// สุดปัง🎉 โค้่ดทำงานได้ถูกต้อง✅ //")
# Out:
# // สุดปัง🎉 โค้่ดทำงานได้ถูกต้อง✅ //
# .

# %% [markdown]
# ###**ตัวอย่างโจทย์ที่ 2** (สาธิตกรณีคำตอบผิด❌)

# %% [markdown]
# ####**🤯 โจทย์ปัญหา**
#
# กำหนดให้ฟังก์ชัน `add_number` เป็นฟังก์ชันสำหรับการลบเลขจำนวนเต็มสองจำนวน
#
# จงเขียนโปรแกรมเพื่อทำให้ฟังก์ชันทำงานได้อย่างสมูบรณ์
#
# ---
#
# ####**✍🏻 ข้อมูลนำเข้า (Input)**
# * `num1`: เลขจำนวนเต็มที่หนึ่ง
# * `num2`: เลขจำนวนเต็มที่สอง
#
# ---
#
# ####**👀 ข้อมูลส่งออก (Output)**
# * `result`: จำนวนเต็มซึ่งเป็นผลลัพธ์จากการลบเลข

# %% [markdown]
# ####**🧑🏻‍💻 เขียนโค้ดคำตอบ**

# %% [markdown]
# ⚠️⚠️⚠️ คำแนะนำ: ไม่มีการใช้คำสั่ง `input()` หรือ `print()` สามารถทดลองใช้คำสั่งดังกล่าวได้ในช่อง "👾Playground"

# %%
def substract_number(num1: int, num2: int) -> int:
  #🚀การประกาศตัวแปรเริ่มต้นสำหรับเก็บคำตอบ (ไม่ต้องแก้ไขส่วนนี้)
  result = 0

  #เขียนโค้ดคำตอบของน้องๆด้านล่างข้อความนี้ 🙋🏻🙋🏻🙋🏻
  result = num1 + num2 
  
  return result

# %% [markdown]
# ####**👾 Playground**

# %%
#ลองเขียนโค้ดเล่นตรงนี้ได้น้า

# %% [markdown]
# ####**🔎 ตรวจสอบผลลัพธ์การทำงาน**

# %%
#รันเซลล์นี้เพื่อตรวจคำตอบ
# %%ipytest -qqs
def test_plus_number():
    assert substract_number(num1=5, num2=5) == approx(0)
    assert substract_number(num1=10, num2=5) == approx(5)
    assert substract_number(num1=20, num2=3) == approx(17)
    assert substract_number(num1=11, num2=4) == approx(7)
    assert substract_number(num1=200, num2=100) == approx(100)
    print("// สุดปัง🎉 โค้่ดทำงานได้ถูกต้อง✅ //")
# Out:
# UsageError: Cell magic `%%ipytest` not found.

# %% [markdown]
# ---
# ---
# ---
# ---

# %% [markdown]
# ###**โจทย์ปัญหาที่ 1 : เงินเดือนโลดแล่น 🌟**

# %% [markdown]
# ####**🤯 โจทย์ปัญหา**
#
# กำหนดอัตราการเลื่อนขั่นเงินเดือนประจำปีดังนี้
#
# ช่วงเงินเดือนเดิม|การปรับเพิ่มเงินเดือน
# -|-
# น้อยกว่า 25001 | 1000
# 25001-35000| 1500
# 35001-50000| 2000
# 50001 เป็นต้นไป| 5000
#
# ---
#
# ####**✍🏻 ข้อมูลนำเข้า (Input)**
# * `salary`: เงินเดือนเดิมของพนักงาน
#
# ---
#
# ####**👀 ข้อมูลส่งออก (Output)**
# * `new_salary` : เงินเดือนของพนักงานหลังจากปรับเพิ่ม
#
# ---
#
# ####**🧐 ตัวอย่างข้อมูลนำเข้าและส่งออก**
#
# input|output
# -|-
# salrary=17500| 18500
# salrary=26500| 28000
# salrary=37500| 39500
# salrary=65000| 74000
#
# ---
#
# ####**💡 คำใบ้ Hint**
# * `if-else`  ต้องมาแล้วล่ะ!
#
# ---

# %% [markdown]
# ####**🧑🏻‍💻 เขียนโค้ดคำตอบ**

# %%
def raise_salary(salary:int)->int:
  #🚀การประกาศตัวแปรเริ่มต้นสำหรับเก็บคำตอบ (ไม่ต้องแก้ไขส่วนนี้)
  new_salary = int() 

  #เขียนโค้ดคำตอบของน้องๆด้านล่างข้อความนี้ 🙋🏻🙋🏻🙋🏻

  if salary <= 25000:
    new_salary = salary + 1000
  elif salary <= 35000 :
    new_salary = salary + 1500
  elif salary <= 50000 :
    new_salary = salary + 2000
  else:
    new_salary = salary + 5000
    

  #ส่งออกคำตอบ
  return new_salary

# %% [markdown]
# ####**👾 Playground**

# %%
#ลองเขียนโค้ดเล่นตรงนี้ได้น้า

# %% [markdown]
# ####**🔎 ตรวจสอบผลลัพธ์การทำงาน**

# %%
#รันเซลล์นี้เพื่อตรวจคำตอบ 
# %%ipytest -qqs
def test_problem2():
    assert raise_salary(salary=10000) == approx(11000)
    assert raise_salary(salary=25000) == approx(26000)
    assert raise_salary(salary=26000) == approx(27500)
    assert raise_salary(salary=35000) == approx(36500)
    assert raise_salary(salary=37000) == approx(39000)
    assert raise_salary(salary=50000) == approx(52000)
    assert raise_salary(salary=70000) == approx(75000)
    print("// สุดปัง🎉🎉🎉🎉🎉 โค้่ดทำงานได้ถูกต้อง✅ //")
# Out:
# // สุดปัง🎉🎉🎉🎉🎉 โค้่ดทำงานได้ถูกต้อง✅ //
# .

# %% [markdown]
# ---
# ---
# ---
# ---

# %% [markdown]
# ###**โจทย์ปัญหาที่ 2 : ตรวจสอบประเภทข้อมูลพนักงาน 🌟🌟**

# %% [markdown]
# ####**🤯 โจทย์ปัญหา**
#
# วันนี้เป็นวันที่วุ่นวายอีกวันหนึ่ง ทีมบัญชีได้พบว่ามีการนำเข้าข้อมูลในระบบที่ผิดปกติ โดยมีการใส่ข้อมูลผิดประเภท เช่น ใส่ชื่อซึ่งเป็นข้อมูลประเภทข้อความ ลงไปในข้อมูลเงินเดือน ซึ่งเป็นประเภทจำนวนเต็ม ทีมบัญชีจึงได้เข้ามาขอความช่วยน้องๆแก้ไขปัญหานี้
#
# ---
#
# ####**✍🏻 ข้อมูลนำเข้า (Input)**
# * `name`: ชื่อของพนักงาน
# * `salary`: เงินเดือนพนักงาน
#
# ---
#
# ####**👀 ข้อมูลส่งออก (Output)**
# * `message`: ข้อความรายงาน ชื่อ และ เงินเดือนของพนักงาน
#
# ⚠️ ในกรณีประเภทข้อมูลไม่ถูกต้องให้รายงานว่าข้อมูลผิดพลาด
#
# ---
#
# ####**🧐 ตัวอย่างข้อมูลนำเข้าและส่งออก**
# input|output
# -|-
# name=สมชาย, salrary=30000|รายงานเงินเดือนพนักงาน คุณสมชาย เงินเดือน30000บาท
# name=30000, salrary=30000|ข้อมูลชื่อไม่ถูกต้อง
# name=สมชาย, salrary=ใจดี | ข้อมูลเงินเดือนไม่ถูกต้อง
# name=30000, salrary=สมชาย| ข้อมูลชื่อและเงินเดือนไม่ถูกต้อง
#
# ---
# ####**💡 คำใบ้ Hint**
# * `type(ตัวแปร)` เป็นคำสั่งสำหรับตรวจสอบประเภทข้อมูล
#
# * การนำค่าจากตัวแปร ใส่ลงในข้อความแบบง่ายๆ
#
# ```python
# message = f"รายงานเงินเดือนพนักงาน คุณ{name} เงินเดือน{salary}บาท"
# ```
#
# ---

# %% [markdown]
# ####**🧑🏻‍💻 เขียนโค้ดคำตอบ**

# %%
def input_employee_info(name :str, salary :int)->str:
  #🚀การประกาศตัวแปรเริ่มต้นสำหรับเก็บคำตอบ (ไม่ต้องแก้ไขส่วนนี้)
  message = str() 

  #🙋🏻เขียนโค้ดคำตอบของน้องๆด้านล่างข้อความนี้ 

  if type(name) == int and type(salary) == int :
    message = "ข้อมูลชื่อไม่ถูกต้อง"
  elif type(name) == str and type(salary) == str :
    message = "ข้อมูลเงินเดือนไม่ถูกต้อง"
  elif type(name) == int and type(salary) == str :
    message = "ข้อมูลชื่อและเงินเดือนไม่ถูกต้อง"
  else :
    message = f"รายงานเงินเดือนพนักงาน คุณ{name} เงินเดือน{salary}บาท"

  #ส่งออกคำตอบ 
  return message

# %% [markdown]
# ####**👾 Playground**

# %%
#ลองเขียนโค้ดเล่นตรงนี้ได้น้า

# %% [markdown]
# ####**🔎 ตรวจสอบผลลัพธ์การทำงาน**

# %%
#รันเซลล์นี้เพื่อตรวจคำตอบ 
# %%ipytest -qqs
def test_problem3():
    assert input_employee_info(name="สมรัก", salary=35000) == "รายงานเงินเดือนพนักงาน คุณสมรัก เงินเดือน35000บาท"
    assert input_employee_info(name="สมชาย", salary=24000) == "รายงานเงินเดือนพนักงาน คุณสมชาย เงินเดือน24000บาท"
    assert input_employee_info(name="ไมค์", salary="ไทสัน") == "ข้อมูลเงินเดือนไม่ถูกต้อง"
    assert input_employee_info(name=80000, salary=46000) == "ข้อมูลชื่อไม่ถูกต้อง"
    assert input_employee_info(name=60000, salary="อภิรักษ์") == "ข้อมูลชื่อและเงินเดือนไม่ถูกต้อง"
    print("// สุดปัง🎉🎉🎉🎉🎉 โค้่ดทำงานได้ถูกต้อง✅ //")
# Out:
# // สุดปัง🎉🎉🎉🎉🎉 โค้่ดทำงานได้ถูกต้อง✅ //
# .

# %% [markdown]
# ###**โจทย์ปัญหาที่ 3 : คัดกรองบัญชีบริษัท 🌟🌟🌟**

# %% [markdown]
# ####**🤯 โจทย์ปัญหา**
#
# ทีมบัญชีต้องการโปรแกรมที่ช่วยในการคัดกรองจำนวน รายรับ รายจ่าย ในการขายอุปกรณ์คอมพิวเตอร์ของบริษัท เพื่อที่จะได้ง่ายต่อการทำงานโดย ทีมบัญชีได้เข้ามาขอความช่วยน้องๆในการสร้างโปรแกรมนี้
#
# ---
#
# ####**✍🏻 ข้อมูลนำเข้า (Input)**
# * `financial_record`: รายการบัญชีรายรับรายจ่าย
#
# เช่นจากตารางบันทึกรายรับรายจ่าย
#
# รายรับ/รายจ่าย | จำนวนเงิน
# -|-
# รายรับ|200
# รายจ่าย|100
# รายจ่าย|50
# รายรับ|100
#
# เมื่อกำหนดให้ จำนวนเต็มบวกแทนรายจ่าย และ จำนวนเต็มลบแทนรายรับ
#
# จะได้ข้อมูลนำเข้าในรูปแบบ List เป็น `[200,-100,-50,100]`
#
# ---
#
# ####**👀 ข้อมูลส่งออก (Output)**
# * result แทน lists ข้อมูลสรุปการเงิน ประกอบด้วยข้อมูลตามลำดับดังนี้
#  * List ข้อมูลรายรับ (รายการจำนวนเต็มบวก)
#  * List ข้อมูลรายจ่าย (รายการจำนวนเต็มลบ)
#  * เงินคงเหลือ]
#
#
# ####**🧐 ตัวอย่างข้อมูลนำเข้าและส่งออก**
#
# input|output
# -|-
# [ 20000,-1000,6000,2000,-3000 ]| [ [ 20000,6000,2000 ], [ -1000,-3000 ], 24000 ]
# [ 0,0,0,"NaN","ERROR",0,300,2500,-500,"NaN" ]| [ [300, 2500], [-500], 2300 ]
#
#
#
# ---
# ####**💡 คำใบ้ Hint**
# * `ใช้ type()` ในการตรวจสอบประเภทตัวแปร
# * `for loop` เป็นคำสั่งสำหรับรันข้อมูลทีละตัวใน lists
#
#
# ---

# %% [markdown]
# ####**🧑🏻‍💻 เขียนโค้ดคำตอบ**

# %%
def sum_record(financial_record):
  #🚀การประกาศตัวแปรเริ่มต้นสำหรับเก็บคำตอบ (ไม่ต้องแก้ไขส่วนนี้)
  result = list()

  neg = []

  #🙋🏻เขียนโค้ดคำตอบของน้องๆด้านล่างข้อความนี้ 
  income = []
  outcome = []
  sum = 0

  for m in financial_record :
    if m != 0 and type(m) != str :
      sum += m
      if(m < 0) :
        outcome.append(m)
      else :
        income.append(m)
  
  result.append(income)
  result.append(outcome)
  result.append(sum)



  #ส่งออกคำตอบ
  return result

# %% [markdown]
# ####**👾 Playground**

# %%
#ลองเขียนโค้ดเล่นตรงนี้ได้น้า
sum_record(["NaN","ERROR",300,2500,-500,"NaN"])

# %% [markdown]
# ####**🔎 ตรวจสอบผลลัพธ์การทำงาน**

# %%
#รันเซลล์นี้เพื่อตรวจคำตอบ 
# %%ipytest -qqs
def test_problem3():
    assert sum_record([20000,-1000,6000,2000,-3000]) == [[20000, 6000, 2000], [-1000, -3000], 24000]
    assert sum_record([100,100,100,100,400]) == [[100, 100, 100, 100, 400], [], 800]
    assert sum_record([500,-3000,-1000,1000,4000]) == [[500, 1000, 4000], [-3000, -1000], 1500]
    assert sum_record([-900,-7000,7000,3000,-4000,-3000]) == [[7000, 3000], [-900, -7000, -4000, -3000], -4900]
    assert sum_record([0,0,3500,"NaN",3000,-4000,-3000,"ERROR"]) == [[3500, 3000], [-4000, -3000], -500]
    assert sum_record([0,0,"NaN","ERROR"]) == [[], [], 0]

    print("// สุดปัง🎉🎉🎉🎉🎉 โค้่ดทำงานได้ถูกต้อง✅ //")
# Out:
# // สุดปัง🎉🎉🎉🎉🎉 โค้่ดทำงานได้ถูกต้อง✅ //
# .
